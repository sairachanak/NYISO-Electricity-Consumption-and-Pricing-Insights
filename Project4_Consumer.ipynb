# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.5)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .appName("Pricing and Load data") \
    .config("spark.driver.memory", "8g") \
    .config("spark.executor.memory", "8g") \
    .config("spark.executor.cores", "4") \
    .getOrCreate()

# %%
combined_data = spark.read.option("header", True).csv("/content/drive/Shareddrives/DATS6450-Project4/combined_data/*.csv")

# %%
from pyspark.sql.functions import month, to_timestamp

combined_data = combined_data.withColumn("timestamp", to_timestamp("timestamp", "MM/dd/yyyy HH:mm:ss"))

streaming_data = combined_data.filter(month("timestamp").isin([3, 6, 9, 12]))
training_data = combined_data.filter(~month("timestamp").isin([3, 6, 9, 12]))

print("Streaming Data Sample")
streaming_data.show(5)

print("Training Data Sample")
training_data.show(5)
# Out:
# Streaming Data Sample
# +-------------------+------+-----+-----+------+----------+---------+----+
# |          timestamp|  Name| PTID| LBMP|Losses|Congestion|Time Zone|Load|
# +-------------------+------+-----+-----+------+----------+---------+----+
# |2001-06-01 00:00:00|CENTRL|61754|22.62| -0.41|      0.00|      EDT|1498|
# |2001-06-01 00:00:00|GENESE|61753|21.99| -1.04|      0.00|      EDT| 841|
# |2001-06-01 00:00:00|MHK VL|61756|23.27|  0.24|      0.00|      EDT| 648|
# |2001-06-01 00:00:00| NORTH|61755|23.01| -0.02|      0.00|      EDT| 661|
# |2001-06-01 00:00:53|CAPITL|61757|16.44|  0.49|      0.00|      EDT| 965|
# +-------------------+------+-----+-----+------+----------+---------+----+
# only showing top 5 rows
#
# Training Data Sample
# +-------------------+------+-----+-----+------+----------+---------+----+
# |          timestamp|  Name| PTID| LBMP|Losses|Congestion|Time Zone|Load|
# +-------------------+------+-----+-----+------+----------+---------+----+
# |2001-05-26 00:00:00|CAPITL|61757|20.52|  1.06|      0.00|      EDT| 985|
# |2001-05-26 00:00:00|CENTRL|61754|19.00| -0.46|      0.00|      EDT|1461|
# |2001-05-26 00:00:00|GENESE|61753|18.88| -0.58|      0.00|      EDT| 830|
# |2001-05-26 00:00:00|MILLWD|61759|20.28|  0.82|      0.00|      EDT| 166|
# |2001-05-26 00:00:00| NORTH|61755|19.44| -0.02|      0.00|      EDT| 659|
# +-------------------+------+-----+-----+------+----------+---------+----+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col

# Convert columns to integer (rounded if necessary)
streaming_data = streaming_data.withColumn("Losses", col("Losses").cast("int")) \
                               .withColumn("Congestion", col("Congestion").cast("int")) \
                               .withColumn("Load", col("Load").cast("int"))

# %%
pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.2.2-py2.py3-none-any.whl.metadata (10.0 kB)
# Downloading kafka_python-2.2.2-py2.py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.3/307.3 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.2.2

# %% [markdown]
# ## Question 1: Random forest Comsumer code

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row, Window
from pyspark.sql import functions as F
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import PipelineModel
from kafka import KafkaConsumer
from collections import defaultdict
import time, json, math


def calculate_rmse(actuals, predictions):
    if not actuals or not predictions or len(actuals) != len(predictions):
        return float('nan')
    squared_errors = [(a - p)**2 for a, p in zip(actuals, predictions)]
    return math.sqrt(sum(squared_errors) / len(squared_errors))

# Kafka Configuration
TOPIC_NAME = "test_streaming"
SASL_MECHANISM = 'SCRAM-SHA-256'
bootstrap_servers = "kafka-28c8ad04-rachanak0611-3f37.j.aivencloud.com:19404"
kafka_password = "AVNS_BpO_fc9_Co4g5b3_ehW"

# Kafka Consumer Setup
consumer = KafkaConsumer(
    TOPIC_NAME,
    auto_offset_reset="earliest",
    bootstrap_servers=bootstrap_servers,
    client_id="CONSUMER_CLIENT_ID",
    group_id="CONSUMER_GROUP_ID",
    sasl_mechanism=SASL_MECHANISM,
    sasl_plain_username="avnadmin",
    sasl_plain_password=kafka_password,
    security_protocol="SASL_SSL",
    ssl_cafile="/content/drive/Shareddrives/DATS6450-Project4/ca.pem",
    max_poll_interval_ms=300000,
    heartbeat_interval_ms=3000,
    session_timeout_ms=10000,
    request_timeout_ms=20000
)

# Spark session
spark = SparkSession.builder.appName("LBMPStreamingModel").getOrCreate()
model = PipelineModel.load("/content/drive/Shareddrives/DATS6450-Project4/rf_lbmp_model_spark")

# Settings
MIN_ROWS_TO_PROCESS = 100
lag_periods = 3
rolling_window_span = 5
buffer_max_size = 10000

# Tracking
global_buffer = []
actuals = []
predictions = []
start_time = time.time()

def process_global_data(data_chunk):
    try:
        df = spark.createDataFrame([Row(**row) for row in data_chunk])

        df = df.withColumn("timestamp", F.to_timestamp("timestamp")) \
               .withColumn("LBMP", F.col("LBMP").cast("float")) \
               .withColumn("Load", F.col("Load").cast("float")) \
               .withColumn("Losses", F.col("Losses").cast("float")) \
               .withColumn("Congestion", F.col("Congestion").cast("float"))

        # Sequential window with row indices
        df = df.withColumn("row_idx", F.monotonically_increasing_id())
        w = Window.orderBy("row_idx")

        for col_name in ["Load", "Losses", "Congestion"]:
            for lag_num in range(1, lag_periods + 1):
                df = df.withColumn(f"{col_name}_lag_{lag_num}", F.lag(col_name, lag_num).over(w))

        rolling_window = w.rowsBetween(-(rolling_window_span - 1), 0)
        for col_name in ["Load", "Losses", "Congestion"]:
            df = df.withColumn(f"{col_name}_ewma", F.avg(col_name).over(rolling_window))

        df = df.withColumn("day_of_week", F.dayofweek("timestamp")) \
               .withColumn("hour", F.hour("timestamp")) \
               .dropna()

        if df.count() == 0:
            print("No valid rows after processing global buffer")
            return

        feature_cols = [c for c in df.columns if c not in ["timestamp", "Name", "PTID", "Time Zone", "LBMP", "row_idx"]]
        prediction_df = df.select(*feature_cols)

        predictions_df = model.transform(prediction_df).select("prediction")
        predicted_values = [row["prediction"] for row in predictions_df.collect()]
        actual_values = [row["LBMP"] for row in df.select("LBMP").collect()]

        for act, pred in zip(actual_values, predicted_values):
            actuals.append(act)
            predictions.append(pred)
            print(f"[{time.time()-start_time:.1f}s] Actual: {act:.2f}, Predicted: {pred:.2f}")

        if len(actuals) % 100 == 0:
            rmse = calculate_rmse(actuals, predictions)
            print(f"\n RMSE after {len(actuals)} predictions: {rmse:.4f}\n")

    except Exception as e:
        print(f"Error processing global data: {str(e)}")

try:
    while True:
        records = consumer.poll(timeout_ms=1000)

        for _, messages in records.items():
            for message in messages:
                try:
                    data = json.loads(message.value.decode('utf-8'))
                    global_buffer.append(data)
                    print(f"Buffered row (total: {len(global_buffer)} rows)")

                    if len(global_buffer) >= MIN_ROWS_TO_PROCESS:
                      data_chunk = global_buffer[:MIN_ROWS_TO_PROCESS]
                      process_global_data(data_chunk)
                      global_buffer = global_buffer[MIN_ROWS_TO_PROCESS:]

                except Exception as e:
                    print(f"Error processing message: {str(e)}")
                    continue

        if len(global_buffer) > buffer_max_size:
            print(f"Trimming global buffer (size: {len(global_buffer)})")
            global_buffer = global_buffer[-buffer_max_size:]

        time.sleep(0.1)

except KeyboardInterrupt:
    print("\nShutting down...")
    print(f"Unprocessed rows remaining: {len(global_buffer)}")
    if len(actuals) > 0:
        rmse = calculate_rmse(actuals, predictions)
        print(f"Final RMSE: {rmse:.4f} from {len(actuals)} predictions")

finally:
    consumer.close()
# Out:
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# ERROR:kafka.consumer.fetcher:Fetch to node 2 failed: NodeNotReadyError: 2
# Buffered row (total: 1 rows)
# Buffered row (total: 2 rows)
# Buffered row (total: 3 rows)
# Buffered row (total: 4 rows)
# Buffered row (total: 5 rows)
# Buffered row (total: 6 rows)
# Buffered row (total: 7 rows)
# Buffered row (total: 8 rows)
# Buffered row (total: 9 rows)
# Buffered row (total: 10 rows)
# Buffered row (total: 11 rows)
# Buffered row (total: 12 rows)
# Buffered row (total: 13 rows)
# Buffered row (total: 14 rows)
# Buffered row (total: 15 rows)
# Buffered row (total: 16 rows)
# Buffered row (total: 17 rows)
# Buffered row (total: 18 rows)
# Buffered row (total: 19 rows)
# Buffered row (total: 20 rows)
# Buffered row (total: 21 rows)
# Buffered row (total: 22 rows)
# Buffered row (total: 23 rows)
# Buffered row (total: 24 rows)
# Buffered row (total: 25 rows)
# Buffered row (total: 26 rows)
# Buffered row (total: 27 rows)
# Buffered row (total: 28 rows)
# Buffered row (total: 29 rows)
# Buffered row (total: 30 rows)
# Buffered row (total: 31 rows)
# Buffered row (total: 32 rows)
# Buffered row (total: 33 rows)
# Buffered row (total: 34 rows)
# Buffered row (total: 35 rows)
# Buffered row (total: 36 rows)
# Buffered row (total: 37 rows)
# Buffered row (total: 38 rows)
# Buffered row (total: 39 rows)
# Buffered row (total: 40 rows)
# Buffered row (total: 41 rows)
# Buffered row (total: 42 rows)
# Buffered row (total: 43 rows)
# Buffered row (total: 44 rows)
# Buffered row (total: 45 rows)
# Buffered row (total: 46 rows)
# Buffered row (total: 47 rows)
# Buffered row (total: 48 rows)
# Buffered row (total: 49 rows)
# Buffered row (total: 50 rows)
# Buffered row (total: 51 rows)
# Buffered row (total: 52 rows)
# Buffered row (total: 53 rows)
# Buffered row (total: 54 rows)
# Buffered row (total: 55 rows)
# Buffered row (total: 56 rows)
# Buffered row (total: 57 rows)
# Buffered row (total: 58 rows)
# Buffered row (total: 59 rows)
# Buffered row (total: 60 rows)
# Buffered row (total: 61 rows)
# Buffered row (total: 62 rows)
# Buffered row (total: 63 rows)
# Buffered row (total: 64 rows)
# Buffered row (total: 65 rows)
# Buffered row (total: 66 rows)
# Buffered row (total: 67 rows)
# Buffered row (total: 68 rows)
# Buffered row (total: 69 rows)
# Buffered row (total: 70 rows)
# Buffered row (total: 71 rows)
# Buffered row (total: 72 rows)
# Buffered row (total: 73 rows)
# Buffered row (total: 74 rows)
# Buffered row (total: 75 rows)
# Buffered row (total: 76 rows)
# Buffered row (total: 77 rows)
# Buffered row (total: 78 rows)
# Buffered row (total: 79 rows)
# Buffered row (total: 80 rows)
# Buffered row (total: 81 rows)
# Buffered row (total: 82 rows)
# Buffered row (total: 83 rows)
# Buffered row (total: 84 rows)
# Buffered row (total: 85 rows)
# Buffered row (total: 86 rows)
# Buffered row (total: 87 rows)
# Buffered row (total: 88 rows)
# Buffered row (total: 89 rows)
# Buffered row (total: 90 rows)
# Buffered row (total: 91 rows)
# Buffered row (total: 92 rows)
# Buffered row (total: 93 rows)
# Buffered row (total: 94 rows)
# Buffered row (total: 95 rows)
# Buffered row (total: 96 rows)
# Buffered row (total: 97 rows)
# Buffered row (total: 98 rows)
# Buffered row (total: 99 rows)
# Buffered row (total: 100 rows)
# [95.8s] Actual: 13.06, Predicted: 25.95
# [95.8s] Actual: 12.87, Predicted: 25.95
# [95.8s] Actual: 12.25, Predicted: 25.95
# [95.8s] Actual: 13.36, Predicted: 25.95
# [95.8s] Actual: 12.59, Predicted: 25.95
# [95.8s] Actual: 13.15, Predicted: 25.95
# [95.8s] Actual: 13.02, Predicted: 25.95
# [95.8s] Actual: 12.99, Predicted: 25.95
# [95.8s] Actual: 12.79, Predicted: 25.95
# [95.8s] Actual: 13.27, Predicted: 25.95
# [95.8s] Actual: 12.51, Predicted: 25.95
# [95.8s] Actual: 13.07, Predicted: 25.95
# [95.8s] Actual: 12.51, Predicted: 25.95
# [95.8s] Actual: 12.98, Predicted: 25.95
# [95.8s] Actual: 12.94, Predicted: 25.95
# [95.8s] Actual: 12.91, Predicted: 25.95
# [95.8s] Actual: 12.11, Predicted: 25.95
# [95.8s] Actual: 12.41, Predicted: 25.95
# [95.8s] Actual: 12.85, Predicted: 25.95
# [95.8s] Actual: 12.62, Predicted: 25.95
# [95.8s] Actual: 13.31, Predicted: 25.95
# [95.8s] Actual: 13.43, Predicted: 25.95
# [95.8s] Actual: 12.58, Predicted: 25.95
# [95.8s] Actual: 13.12, Predicted: 25.95
# [95.8s] Actual: 12.57, Predicted: 25.95
# [95.8s] Actual: 13.01, Predicted: 25.95
# [95.8s] Actual: -52.56, Predicted: 25.95
# [95.8s] Actual: -49.49, Predicted: 25.95
# [95.8s] Actual: -51.52, Predicted: 25.95
# [95.8s] Actual: -49.43, Predicted: 25.95
# [95.8s] Actual: -51.08, Predicted: 25.95
# [95.8s] Actual: -50.88, Predicted: 25.95
# [95.8s] Actual: -49.43, Predicted: 25.95
# [95.8s] Actual: -51.19, Predicted: 25.95
# [95.8s] Actual: -50.88, Predicted: 25.95
# [95.8s] Actual: -51.52, Predicted: 25.95
# [95.8s] Actual: -50.89, Predicted: 25.95
# [95.8s] Actual: -50.25, Predicted: 25.95
# [95.8s] Actual: -47.93, Predicted: 26.95
# [95.8s] Actual: -52.19, Predicted: 26.24
# [95.8s] Actual: -49.28, Predicted: 26.23
# [95.8s] Actual: -51.53, Predicted: 26.04
# [95.8s] Actual: -49.13, Predicted: 25.95
# [95.8s] Actual: -51.21, Predicted: 25.95
# [95.8s] Actual: -50.91, Predicted: 25.95
# [95.8s] Actual: -50.90, Predicted: 25.95
# [95.8s] Actual: 12.16, Predicted: 25.95
# [95.8s] Actual: 12.64, Predicted: 25.95
# [95.8s] Actual: 12.56, Predicted: 25.95
# [95.8s] Actual: 12.35, Predicted: 25.95
# [95.8s] Actual: 12.17, Predicted: 25.95
# [95.8s] Actual: 12.72, Predicted: 25.95
# [95.8s] Actual: 12.17, Predicted: 25.95
# [95.8s] Actual: 12.64, Predicted: 25.95
# [95.8s] Actual: 11.80, Predicted: 25.95
# [95.8s] Actual: 12.87, Predicted: 25.95
# [95.8s] Actual: 12.71, Predicted: 25.95
# [95.8s] Actual: 12.63, Predicted: 25.95
# [95.8s] Actual: 12.55, Predicted: 25.95
# [95.8s] Actual: 12.56, Predicted: 25.95
# [95.8s] Actual: 12.33, Predicted: 25.95
# [95.8s] Actual: 12.92, Predicted: 25.95
# [95.8s] Actual: 12.21, Predicted: 25.95
# [95.8s] Actual: 12.18, Predicted: 25.95
# [95.8s] Actual: 12.58, Predicted: 25.95
# [95.8s] Actual: 18.52, Predicted: 25.95
# [95.8s] Actual: 19.34, Predicted: 25.95
# [95.8s] Actual: 18.51, Predicted: 25.95
# [95.8s] Actual: 19.11, Predicted: 25.95
# [95.8s] Actual: 15.86, Predicted: 25.95
# [95.8s] Actual: 15.76, Predicted: 25.95
# [95.8s] Actual: 15.67, Predicted: 25.95
# [95.8s] Actual: 15.37, Predicted: 25.95
# [95.8s] Actual: 20.69, Predicted: 25.95
# [95.8s] Actual: 21.61, Predicted: 25.95
# [95.8s] Actual: 20.68, Predicted: 25.95
# [95.8s] Actual: 21.48, Predicted: 25.95
# [95.8s] Actual: 21.35, Predicted: 25.95
# [95.8s] Actual: 19.97, Predicted: 25.95
# [95.8s] Actual: 13.23, Predicted: 25.95
# [95.8s] Actual: 12.91, Predicted: 25.95
# [95.8s] Actual: 13.59, Predicted: 25.95
# [95.8s] Actual: 13.37, Predicted: 25.95
# [95.8s] Actual: 12.81, Predicted: 25.95
# [95.8s] Actual: 13.29, Predicted: 25.95
# [95.8s] Actual: 13.21, Predicted: 25.95
# [95.8s] Actual: 12.98, Predicted: 25.95
# [95.8s] Actual: 12.36, Predicted: 25.95
# [95.8s] Actual: 12.82, Predicted: 25.95
# [95.8s] Actual: 12.98, Predicted: 25.95
# [95.8s] Actual: -52.30, Predicted: 25.95
# [95.8s] Actual: -49.46, Predicted: 25.95
# [95.8s] Actual: -51.19, Predicted: 25.95
# [95.8s] Actual: -50.89, Predicted: 25.95
# [95.8s] Actual: -50.87, Predicted: 25.95
# [95.8s] Actual: -49.99, Predicted: 25.95
# [95.8s] Actual: -51.51, Predicted: 25.95
# Buffered row (total: 1 rows)
# Buffered row (total: 2 rows)
# Buffered row (total: 3 rows)
# Buffered row (total: 4 rows)
# Buffered row (total: 5 rows)
# Buffered row (total: 6 rows)
# Buffered row (total: 7 rows)
# Buffered row (total: 8 rows)
# Buffered row (total: 9 rows)
# Buffered row (total: 10 rows)
# Buffered row (total: 11 rows)
# Buffered row (total: 12 rows)
# Buffered row (total: 13 rows)
# Buffered row (total: 14 rows)
# Buffered row (total: 15 rows)
# Buffered row (total: 16 rows)
# Buffered row (total: 17 rows)
# Buffered row (total: 18 rows)
# Buffered row (total: 19 rows)
# Buffered row (total: 20 rows)
# Buffered row (total: 21 rows)
# Buffered row (total: 22 rows)
# Buffered row (total: 23 rows)
# Buffered row (total: 24 rows)
# Buffered row (total: 25 rows)
# Buffered row (total: 26 rows)
# Buffered row (total: 27 rows)
# Buffered row (total: 28 rows)
# Buffered row (total: 29 rows)
# Buffered row (total: 30 rows)
# Buffered row (total: 31 rows)
# Buffered row (total: 32 rows)
# Buffered row (total: 33 rows)
# Buffered row (total: 34 rows)
# Buffered row (total: 35 rows)
# Buffered row (total: 36 rows)
# Buffered row (total: 37 rows)
# Buffered row (total: 38 rows)
# Buffered row (total: 39 rows)
# Buffered row (total: 40 rows)
# Buffered row (total: 41 rows)
# Buffered row (total: 42 rows)
# Buffered row (total: 43 rows)
# Buffered row (total: 44 rows)
# Buffered row (total: 45 rows)
# Buffered row (total: 46 rows)
# Buffered row (total: 47 rows)
# Buffered row (total: 48 rows)
# Buffered row (total: 49 rows)
# Buffered row (total: 50 rows)
# Buffered row (total: 51 rows)
# Buffered row (total: 52 rows)
# Buffered row (total: 53 rows)
# Buffered row (total: 54 rows)
# Buffered row (total: 55 rows)
# Buffered row (total: 56 rows)
# Buffered row (total: 57 rows)
# Buffered row (total: 58 rows)
# Buffered row (total: 59 rows)
# Buffered row (total: 60 rows)
# Buffered row (total: 61 rows)
# Buffered row (total: 62 rows)
# Buffered row (total: 63 rows)
# Buffered row (total: 64 rows)
# Buffered row (total: 65 rows)
# Buffered row (total: 66 rows)
# Buffered row (total: 67 rows)
# Buffered row (total: 68 rows)
# Buffered row (total: 69 rows)
# Buffered row (total: 70 rows)
# Buffered row (total: 71 rows)
# Buffered row (total: 72 rows)
# Buffered row (total: 73 rows)
# Buffered row (total: 74 rows)
# Buffered row (total: 75 rows)
# Buffered row (total: 76 rows)
# Buffered row (total: 77 rows)
# Buffered row (total: 78 rows)
# Buffered row (total: 79 rows)
# Buffered row (total: 80 rows)
# Buffered row (total: 81 rows)
# Buffered row (total: 82 rows)
# Buffered row (total: 83 rows)
# Buffered row (total: 84 rows)
# Buffered row (total: 85 rows)
#
# Shutting down...
# Unprocessed rows remaining: 85
# Final RMSE: 41.7833 from 97 predictions
# WARNING:kafka.coordinator:Heartbeat thread did not fully terminate during close

# %% [markdown]
# The random foresy model seems to be overfitted hence, lets work on a different model which is Linear regression

# %% [markdown]
# ##Question 1: Consumer with Linear regression model

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row, Window
from pyspark.sql import functions as F
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import PipelineModel
from kafka import KafkaConsumer
from collections import defaultdict
import time, json, math


def calculate_rmse(actuals, predictions):
    if not actuals or not predictions or len(actuals) != len(predictions):
        return float('nan')
    squared_errors = [(a - p)**2 for a, p in zip(actuals, predictions)]
    return math.sqrt(sum(squared_errors) / len(squared_errors))

# Kafka Configuration
TOPIC_NAME = "test_streaming"
SASL_MECHANISM = 'SCRAM-SHA-256'
bootstrap_servers = "kafka-28c8ad04-rachanak0611-3f37.j.aivencloud.com:19404"
kafka_password = "AVNS_BpO_fc9_Co4g5b3_ehW"

# Kafka Consumer Setup
consumer = KafkaConsumer(
    TOPIC_NAME,
    auto_offset_reset="earliest",
    bootstrap_servers=bootstrap_servers,
    client_id="CONSUMER_CLIENT_ID",
    group_id="CONSUMER_GROUP_ID",
    sasl_mechanism=SASL_MECHANISM,
    sasl_plain_username="avnadmin",
    sasl_plain_password=kafka_password,
    security_protocol="SASL_SSL",
    ssl_cafile="/content/drive/Shareddrives/DATS6450-Project4/ca.pem",
    max_poll_interval_ms=300000,
    heartbeat_interval_ms=3000,
    session_timeout_ms=10000,
    request_timeout_ms=20000
)

last_processed_index = 0


# Spark session
spark = SparkSession.builder.appName("LBMPStreamingModel").getOrCreate()
model = PipelineModel.load("/content/drive/Shareddrives/DATS6450-Project4/lr_lbmp_model_spark")

# Settings
MIN_ROWS_TO_PROCESS = 100
lag_periods = 3
rolling_window_span = 5
buffer_max_size = 10000

# Tracking
global_buffer = []
actuals = []
predictions = []
start_time = time.time()

def process_global_data(data_chunk):
    try:
        df = spark.createDataFrame([Row(**row) for row in data_chunk])

        df = df.withColumn("timestamp", F.to_timestamp("timestamp")) \
               .withColumn("LBMP", F.col("LBMP").cast("float")) \
               .withColumn("Load", F.col("Load").cast("float")) \
               .withColumn("Losses", F.col("Losses").cast("float")) \
               .withColumn("Congestion", F.col("Congestion").cast("float"))

        # Sequential window with row indices
        df = df.withColumn("row_idx", F.monotonically_increasing_id())
        w = Window.orderBy("row_idx")

        for col_name in ["Load", "Losses", "Congestion"]:
            for lag_num in range(1, lag_periods + 1):
                df = df.withColumn(f"{col_name}_lag_{lag_num}", F.lag(col_name, lag_num).over(w))

        rolling_window = w.rowsBetween(-(rolling_window_span - 1), 0)
        for col_name in ["Load", "Losses", "Congestion"]:
            df = df.withColumn(f"{col_name}_ewma", F.avg(col_name).over(rolling_window))

        df = df.withColumn("day_of_week", F.dayofweek("timestamp")) \
               .withColumn("hour", F.hour("timestamp")) \
               .dropna()

        if df.count() == 0:
            print("No valid rows after processing global buffer")
            return

        latest_row = df.orderBy("timestamp", ascending=False).limit(1)
        lbmp_value = latest_row.select("LBMP").collect()[0]["LBMP"]
        feature_cols = [c for c in latest_row.columns if c not in ["timestamp", "Name", "PTID", "Time Zone", "LBMP", "row_idx"]]
        prediction_df = latest_row.select(*feature_cols)

        prediction = model.transform(prediction_df)
        predicted = prediction.select("prediction").collect()[0]["prediction"]

        actuals.append(lbmp_value)
        predictions.append(predicted)

        print(f"[{time.time()-start_time:.1f}s] Actual: {lbmp_value:.2f}, Predicted: {predicted:.2f}")

        if len(actuals) % 10 == 0:
            rmse = calculate_rmse(actuals, predictions)
            print(f"Current RMSE: {rmse:.4f}")

    except Exception as e:
        print(f"Error processing global data: {str(e)}")

try:
    while True:
        records = consumer.poll(timeout_ms=1000)

        for _, messages in records.items():
            for message in messages:
                try:
                    data = json.loads(message.value.decode('utf-8'))
                    global_buffer.append(data)
                    print(f"Buffered row (total: {len(global_buffer)} rows)")

                    if len(global_buffer) >= MIN_ROWS_TO_PROCESS:
                        #data_chunk = global_buffer[:MIN_ROWS_TO_PROCESS]
                        process_global_data(global_buffer)

                except Exception as e:
                    print(f"Error processing message: {str(e)}")
                    continue

                if len(global_buffer) >= MIN_ROWS_TO_PROCESS:
                    data_chunk = global_buffer[last_processed_index:]
                    if data_chunk:
                        process_global_data(data_chunk)
                        last_processed_index = len(global_buffer)


        time.sleep(0.1)

except KeyboardInterrupt:
    print("\nShutting down...")
    print(f"Unprocessed rows remaining: {len(global_buffer)}")
    if len(actuals) > 0:
        rmse = calculate_rmse(actuals, predictions)
        print(f"Final RMSE: {rmse:.4f} from {len(actuals)} predictions")

finally:
    consumer.close()
# Out:
# Buffered row (total: 1 rows)
# Buffered row (total: 2 rows)
# Buffered row (total: 3 rows)
# Buffered row (total: 4 rows)
# Buffered row (total: 5 rows)
# Buffered row (total: 6 rows)
# Buffered row (total: 7 rows)
# Buffered row (total: 8 rows)
# Buffered row (total: 9 rows)
# Buffered row (total: 10 rows)
# Buffered row (total: 11 rows)
# Buffered row (total: 12 rows)
# Buffered row (total: 13 rows)
# Buffered row (total: 14 rows)
# Buffered row (total: 15 rows)
# Buffered row (total: 16 rows)
# Buffered row (total: 17 rows)
# Buffered row (total: 18 rows)
# Buffered row (total: 19 rows)
# Buffered row (total: 20 rows)
# Buffered row (total: 21 rows)
# Buffered row (total: 22 rows)
# Buffered row (total: 23 rows)
# Buffered row (total: 24 rows)
# Buffered row (total: 25 rows)
# Buffered row (total: 26 rows)
# Buffered row (total: 27 rows)
# Buffered row (total: 28 rows)
# Buffered row (total: 29 rows)
# Buffered row (total: 30 rows)
# Buffered row (total: 31 rows)
# Buffered row (total: 32 rows)
# Buffered row (total: 33 rows)
# Buffered row (total: 34 rows)
# Buffered row (total: 35 rows)
# Buffered row (total: 36 rows)
# Buffered row (total: 37 rows)
# Buffered row (total: 38 rows)
# Buffered row (total: 39 rows)
# Buffered row (total: 40 rows)
# Buffered row (total: 41 rows)
# Buffered row (total: 42 rows)
# Buffered row (total: 43 rows)
# Buffered row (total: 44 rows)
# Buffered row (total: 45 rows)
# Buffered row (total: 46 rows)
# Buffered row (total: 47 rows)
# Buffered row (total: 48 rows)
# Buffered row (total: 49 rows)
# Buffered row (total: 50 rows)
# Buffered row (total: 51 rows)
# Buffered row (total: 52 rows)
# Buffered row (total: 53 rows)
# Buffered row (total: 54 rows)
# Buffered row (total: 55 rows)
# Buffered row (total: 56 rows)
# Buffered row (total: 57 rows)
# Buffered row (total: 58 rows)
# Buffered row (total: 59 rows)
# Buffered row (total: 60 rows)
# Buffered row (total: 61 rows)
# Buffered row (total: 62 rows)
# Buffered row (total: 63 rows)
# Buffered row (total: 64 rows)
# Buffered row (total: 65 rows)
# Buffered row (total: 66 rows)
# Buffered row (total: 67 rows)
# Buffered row (total: 68 rows)
# Buffered row (total: 69 rows)
# Buffered row (total: 70 rows)
# Buffered row (total: 71 rows)
# Buffered row (total: 72 rows)
# Buffered row (total: 73 rows)
# Buffered row (total: 74 rows)
# Buffered row (total: 75 rows)
# Buffered row (total: 76 rows)
# Buffered row (total: 77 rows)
# Buffered row (total: 78 rows)
# Buffered row (total: 79 rows)
# Buffered row (total: 80 rows)
# Buffered row (total: 81 rows)
# Buffered row (total: 82 rows)
# Buffered row (total: 83 rows)
# Buffered row (total: 84 rows)
# Buffered row (total: 85 rows)
# Buffered row (total: 86 rows)
# Buffered row (total: 87 rows)
# Buffered row (total: 88 rows)
# Buffered row (total: 89 rows)
# Buffered row (total: 90 rows)
# Buffered row (total: 91 rows)
# Buffered row (total: 92 rows)
# Buffered row (total: 93 rows)
# Buffered row (total: 94 rows)
# Buffered row (total: 95 rows)
# Buffered row (total: 96 rows)
# Buffered row (total: 97 rows)
# Buffered row (total: 98 rows)
# Buffered row (total: 99 rows)
# Buffered row (total: 100 rows)
# [86.1s] Actual: 36.80, Predicted: 29.35
# [87.7s] Actual: 36.80, Predicted: 29.35
# Buffered row (total: 101 rows)
# [89.2s] Actual: 36.80, Predicted: 29.35
# No valid rows after processing global buffer
# Buffered row (total: 102 rows)
# [90.9s] Actual: 36.80, Predicted: 29.35
# No valid rows after processing global buffer
# Buffered row (total: 103 rows)
# [93.3s] Actual: 25.71, Predicted: 31.86
# No valid rows after processing global buffer
# Buffered row (total: 104 rows)
# [95.9s] Actual: 25.71, Predicted: 31.86
# No valid rows after processing global buffer
# Buffered row (total: 105 rows)
# [97.6s] Actual: 25.71, Predicted: 31.86
# No valid rows after processing global buffer
# Buffered row (total: 106 rows)
# [99.5s] Actual: 25.71, Predicted: 31.86
# No valid rows after processing global buffer
# Buffered row (total: 107 rows)
# [101.3s] Actual: 35.17, Predicted: 34.44
# No valid rows after processing global buffer
# Buffered row (total: 108 rows)
# [103.0s] Actual: 35.17, Predicted: 34.44
# Current RMSE: 6.1174
# No valid rows after processing global buffer
# Buffered row (total: 109 rows)
# [104.6s] Actual: 35.17, Predicted: 34.44
# No valid rows after processing global buffer
# Buffered row (total: 110 rows)
# [107.0s] Actual: 35.26, Predicted: 31.24
# No valid rows after processing global buffer
# Buffered row (total: 111 rows)
# [109.5s] Actual: 35.26, Predicted: 31.24
# No valid rows after processing global buffer
# Buffered row (total: 112 rows)
# [111.5s] Actual: 35.26, Predicted: 31.24
# No valid rows after processing global buffer
# Buffered row (total: 113 rows)
# [113.3s] Actual: 35.26, Predicted: 31.24
# No valid rows after processing global buffer
# Buffered row (total: 114 rows)
# [115.0s] Actual: 35.26, Predicted: 31.24
# No valid rows after processing global buffer
# Buffered row (total: 115 rows)
# [116.8s] Actual: 35.26, Predicted: 31.24
# No valid rows after processing global buffer
# Buffered row (total: 116 rows)
# [118.6s] Actual: 25.08, Predicted: 25.14
# No valid rows after processing global buffer
# Buffered row (total: 117 rows)
# [120.3s] Actual: 25.08, Predicted: 25.14
# No valid rows after processing global buffer
# Buffered row (total: 118 rows)
# [122.9s] Actual: 25.08, Predicted: 25.14
# Current RMSE: 4.8578
# No valid rows after processing global buffer
# Buffered row (total: 119 rows)
# [125.3s] Actual: 25.08, Predicted: 25.14
# No valid rows after processing global buffer
# Buffered row (total: 120 rows)
# [127.0s] Actual: 25.08, Predicted: 25.14
# No valid rows after processing global buffer
# Buffered row (total: 121 rows)
# [128.8s] Actual: 34.52, Predicted: 33.89
# No valid rows after processing global buffer
# Buffered row (total: 122 rows)
# [130.6s] Actual: 34.52, Predicted: 33.89
# No valid rows after processing global buffer
# Buffered row (total: 123 rows)
# [132.6s] Actual: 34.52, Predicted: 33.89
# No valid rows after processing global buffer
# Buffered row (total: 124 rows)
# [134.5s] Actual: 34.52, Predicted: 33.89
# No valid rows after processing global buffer
# Buffered row (total: 125 rows)
# [137.0s] Actual: 34.52, Predicted: 33.89
# No valid rows after processing global buffer
# Buffered row (total: 126 rows)
# [139.4s] Actual: 34.52, Predicted: 33.89
# No valid rows after processing global buffer
# Buffered row (total: 127 rows)
# [141.1s] Actual: 34.52, Predicted: 33.89
# No valid rows after processing global buffer
# Buffered row (total: 128 rows)
# [142.8s] Actual: 36.68, Predicted: 36.85
# Current RMSE: 3.9782
# No valid rows after processing global buffer
# Buffered row (total: 129 rows)
# [144.5s] Actual: 36.68, Predicted: 36.85
# No valid rows after processing global buffer
# Buffered row (total: 130 rows)
# [146.3s] Actual: 36.68, Predicted: 36.85
# No valid rows after processing global buffer
# Buffered row (total: 131 rows)
# [148.0s] Actual: 36.68, Predicted: 36.85
# No valid rows after processing global buffer
# Buffered row (total: 132 rows)
# [150.0s] Actual: 36.68, Predicted: 36.85
# No valid rows after processing global buffer
# Buffered row (total: 133 rows)
# [152.6s] Actual: 36.68, Predicted: 36.85
# No valid rows after processing global buffer
# Buffered row (total: 134 rows)
# [154.5s] Actual: 34.58, Predicted: 32.60
# No valid rows after processing global buffer
# Buffered row (total: 135 rows)
# [156.4s] Actual: 34.58, Predicted: 32.60
# No valid rows after processing global buffer
# Buffered row (total: 136 rows)
# [158.1s] Actual: 34.58, Predicted: 32.60
# No valid rows after processing global buffer
# Buffered row (total: 137 rows)
# [159.7s] Actual: 34.58, Predicted: 32.60
# No valid rows after processing global buffer
# Buffered row (total: 138 rows)
# [161.4s] Actual: 34.58, Predicted: 32.60
# Current RMSE: 3.5162
# No valid rows after processing global buffer
# Buffered row (total: 139 rows)
# [163.0s] Actual: 34.29, Predicted: 28.24
# No valid rows after processing global buffer
# Buffered row (total: 140 rows)
# [165.5s] Actual: 34.29, Predicted: 28.24
# No valid rows after processing global buffer
# Buffered row (total: 141 rows)
# [168.2s] Actual: 34.29, Predicted: 28.24
# No valid rows after processing global buffer
# Buffered row (total: 142 rows)
# [169.8s] Actual: 34.29, Predicted: 28.24
# No valid rows after processing global buffer
# Buffered row (total: 143 rows)
# [171.5s] Actual: 34.29, Predicted: 28.24
# No valid rows after processing global buffer
# Buffered row (total: 144 rows)
# [173.2s] Actual: 34.55, Predicted: 27.78
# No valid rows after processing global buffer
# Buffered row (total: 145 rows)
# [174.9s] Actual: 34.55, Predicted: 27.78
# No valid rows after processing global buffer
# Buffered row (total: 146 rows)
# [176.7s] Actual: 34.55, Predicted: 27.78
# No valid rows after processing global buffer
# Buffered row (total: 147 rows)
# [178.6s] Actual: 34.55, Predicted: 27.78
# No valid rows after processing global buffer
# Buffered row (total: 148 rows)
# [181.4s] Actual: 34.55, Predicted: 27.78
# Current RMSE: 4.2587
# No valid rows after processing global buffer
# Buffered row (total: 149 rows)
# [183.4s] Actual: 34.65, Predicted: 26.94
# No valid rows after processing global buffer
# Buffered row (total: 150 rows)
# [185.1s] Actual: 34.65, Predicted: 26.94
# No valid rows after processing global buffer
# Buffered row (total: 151 rows)
# [186.7s] Actual: 34.65, Predicted: 26.94
# No valid rows after processing global buffer
# Buffered row (total: 152 rows)
# [188.3s] Actual: 34.65, Predicted: 26.94
# No valid rows after processing global buffer
# Buffered row (total: 153 rows)
# [189.9s] Actual: 34.65, Predicted: 26.94
# No valid rows after processing global buffer
# Buffered row (total: 154 rows)
# [191.6s] Actual: 34.65, Predicted: 26.94
# No valid rows after processing global buffer
# Buffered row (total: 155 rows)
# [193.7s] Actual: 40.48, Predicted: 37.27
# No valid rows after processing global buffer
# Buffered row (total: 156 rows)
# [196.3s] Actual: 40.48, Predicted: 37.27
# No valid rows after processing global buffer
# Buffered row (total: 157 rows)
# [198.2s] Actual: 40.48, Predicted: 37.27
# No valid rows after processing global buffer
# Buffered row (total: 158 rows)
# [199.8s] Actual: 40.48, Predicted: 37.27
# Current RMSE: 4.6627
# No valid rows after processing global buffer
# Buffered row (total: 159 rows)
# [201.4s] Actual: 40.48, Predicted: 37.27
# No valid rows after processing global buffer
# Buffered row (total: 160 rows)
# [203.2s] Actual: 40.48, Predicted: 37.27
# No valid rows after processing global buffer
# Buffered row (total: 161 rows)
# [204.9s] Actual: 41.52, Predicted: 34.33
# No valid rows after processing global buffer
# Buffered row (total: 162 rows)
# [206.6s] Actual: 41.52, Predicted: 34.33
# No valid rows after processing global buffer
# Buffered row (total: 163 rows)
# [209.0s] Actual: 41.52, Predicted: 34.33
# No valid rows after processing global buffer
# Buffered row (total: 164 rows)
# [211.5s] Actual: 41.52, Predicted: 34.33
# No valid rows after processing global buffer
# Buffered row (total: 165 rows)
# [213.2s] Actual: 35.61, Predicted: 33.82
# No valid rows after processing global buffer
# Buffered row (total: 166 rows)
# [214.9s] Actual: 35.61, Predicted: 33.82
# No valid rows after processing global buffer
# Buffered row (total: 167 rows)
# [216.5s] Actual: 24.21, Predicted: 24.58
# No valid rows after processing global buffer
# Buffered row (total: 168 rows)
# [218.2s] Actual: 24.21, Predicted: 24.58
# Current RMSE: 4.6887
# No valid rows after processing global buffer
# Buffered row (total: 169 rows)
# [219.8s] Actual: 24.21, Predicted: 24.58
# No valid rows after processing global buffer
# Buffered row (total: 170 rows)
# [221.4s] Actual: 24.21, Predicted: 24.58
# No valid rows after processing global buffer
# Buffered row (total: 171 rows)
# [224.0s] Actual: 24.21, Predicted: 24.58
# No valid rows after processing global buffer
# Buffered row (total: 172 rows)
# [226.3s] Actual: 21.55, Predicted: 30.14
# No valid rows after processing global buffer
# Buffered row (total: 173 rows)
# [228.0s] Actual: 21.55, Predicted: 30.14
# No valid rows after processing global buffer
# Buffered row (total: 174 rows)
# [229.6s] Actual: 21.55, Predicted: 30.14
# No valid rows after processing global buffer
# Buffered row (total: 175 rows)
# [231.2s] Actual: 21.55, Predicted: 30.14
# No valid rows after processing global buffer
# Buffered row (total: 176 rows)
# [232.9s] Actual: 23.81, Predicted: 31.20
# No valid rows after processing global buffer
# Buffered row (total: 177 rows)
# [234.5s] Actual: 23.81, Predicted: 31.20
# No valid rows after processing global buffer
# Buffered row (total: 178 rows)
# [236.3s] Actual: 23.81, Predicted: 31.20
# Current RMSE: 4.9976
# No valid rows after processing global buffer
# Buffered row (total: 179 rows)
# [238.8s] Actual: 23.81, Predicted: 31.20
# No valid rows after processing global buffer
# Buffered row (total: 180 rows)
# [241.0s] Actual: 23.81, Predicted: 31.20
# No valid rows after processing global buffer
# Buffered row (total: 181 rows)
# [242.7s] Actual: 23.81, Predicted: 31.20
# No valid rows after processing global buffer
# Buffered row (total: 182 rows)
# [244.3s] Actual: 22.98, Predicted: 30.26
# No valid rows after processing global buffer
# Buffered row (total: 183 rows)
# [246.0s] Actual: 22.98, Predicted: 30.26
# No valid rows after processing global buffer
# Buffered row (total: 184 rows)
# [247.6s] Actual: 22.98, Predicted: 30.26
# No valid rows after processing global buffer
# Buffered row (total: 185 rows)
# [249.2s] Actual: 22.98, Predicted: 30.26
# No valid rows after processing global buffer
# Buffered row (total: 186 rows)
# [251.2s] Actual: 22.98, Predicted: 30.26
# No valid rows after processing global buffer
# Buffered row (total: 187 rows)
# [254.2s] Actual: 22.98, Predicted: 30.26
# No valid rows after processing global buffer
# Buffered row (total: 188 rows)
# [256.1s] Actual: 22.98, Predicted: 30.26
# Current RMSE: 5.3053
# No valid rows after processing global buffer
# Buffered row (total: 189 rows)
# [257.7s] Actual: 21.58, Predicted: 34.30
# No valid rows after processing global buffer
# Buffered row (total: 190 rows)
# [259.4s] Actual: 21.58, Predicted: 34.30
# No valid rows after processing global buffer
# Buffered row (total: 191 rows)
# [261.2s] Actual: 21.58, Predicted: 34.30
# No valid rows after processing global buffer
# Buffered row (total: 192 rows)
# [262.8s] Actual: 21.58, Predicted: 34.30
# No valid rows after processing global buffer
# Buffered row (total: 193 rows)
# [264.7s] Actual: 21.58, Predicted: 34.30
# No valid rows after processing global buffer
# Buffered row (total: 194 rows)
# [267.0s] Actual: 24.06, Predicted: 21.25
# No valid rows after processing global buffer
# Buffered row (total: 195 rows)
# [269.6s] Actual: 24.06, Predicted: 21.25
# No valid rows after processing global buffer
# Buffered row (total: 196 rows)
# [271.3s] Actual: 24.06, Predicted: 21.25
# No valid rows after processing global buffer
# Buffered row (total: 197 rows)
# [272.9s] Actual: 24.06, Predicted: 21.25
# No valid rows after processing global buffer
# Buffered row (total: 198 rows)
# [274.6s] Actual: 24.06, Predicted: 21.25
# Current RMSE: 5.8151
# No valid rows after processing global buffer
# Buffered row (total: 199 rows)
# [276.3s] Actual: 22.82, Predicted: 32.22
# No valid rows after processing global buffer
# Buffered row (total: 200 rows)
# [277.9s] Actual: 22.82, Predicted: 32.22
# No valid rows after processing global buffer
# Buffered row (total: 201 rows)
# [279.6s] Actual: 22.82, Predicted: 32.22
# No valid rows after processing global buffer
# Buffered row (total: 202 rows)
# [282.4s] Actual: 22.82, Predicted: 32.22
# No valid rows after processing global buffer
# Buffered row (total: 203 rows)
# [285.0s] Actual: 21.70, Predicted: 31.84
# No valid rows after processing global buffer
# Buffered row (total: 204 rows)
# [286.6s] Actual: 21.70, Predicted: 31.84
# No valid rows after processing global buffer
# Buffered row (total: 205 rows)
# [288.2s] Actual: 21.70, Predicted: 31.84
# No valid rows after processing global buffer
# Buffered row (total: 206 rows)
# [289.9s] Actual: 21.70, Predicted: 31.84
# No valid rows after processing global buffer
# Buffered row (total: 207 rows)
# [291.5s] Actual: 23.35, Predicted: 27.27
# No valid rows after processing global buffer
# Buffered row (total: 208 rows)
# [293.2s] Actual: 23.35, Predicted: 27.27
# Current RMSE: 6.1620
# No valid rows after processing global buffer
# Buffered row (total: 209 rows)
# [295.3s] Actual: 23.35, Predicted: 27.27
# No valid rows after processing global buffer
# Buffered row (total: 210 rows)
# [297.8s] Actual: 23.35, Predicted: 27.27
# No valid rows after processing global buffer
# Buffered row (total: 211 rows)
# [299.8s] Actual: 23.35, Predicted: 27.27
# No valid rows after processing global buffer
# Buffered row (total: 212 rows)
# [301.6s] Actual: 22.87, Predicted: 30.35
# No valid rows after processing global buffer
# Buffered row (total: 213 rows)
# [303.3s] Actual: 22.87, Predicted: 30.35
# No valid rows after processing global buffer
# Buffered row (total: 214 rows)
# [304.9s] Actual: 22.87, Predicted: 30.35
# No valid rows after processing global buffer
# Buffered row (total: 215 rows)
# [306.6s] Actual: 22.83, Predicted: 32.10
# No valid rows after processing global buffer
# Buffered row (total: 216 rows)
# [308.2s] Actual: 22.83, Predicted: 32.10
# No valid rows after processing global buffer
# Buffered row (total: 217 rows)
# [310.5s] Actual: 22.83, Predicted: 32.10
# No valid rows after processing global buffer
# Buffered row (total: 218 rows)
# [313.1s] Actual: 22.83, Predicted: 32.10
# Current RMSE: 6.2812
# No valid rows after processing global buffer
# Buffered row (total: 219 rows)
# [314.8s] Actual: 22.83, Predicted: 32.10
# No valid rows after processing global buffer
# Buffered row (total: 220 rows)
# [316.5s] Actual: 22.83, Predicted: 32.10
# No valid rows after processing global buffer
# Buffered row (total: 221 rows)
# [318.2s] Actual: 21.61, Predicted: 36.76
# No valid rows after processing global buffer
# Buffered row (total: 222 rows)
# [319.8s] Actual: 21.61, Predicted: 36.76
# No valid rows after processing global buffer
# Buffered row (total: 223 rows)
# [321.5s] Actual: 21.61, Predicted: 36.76
# No valid rows after processing global buffer
# Buffered row (total: 224 rows)
# [323.4s] Actual: 21.61, Predicted: 36.76
# No valid rows after processing global buffer
# Buffered row (total: 225 rows)
# [326.0s] Actual: 21.61, Predicted: 36.76
# No valid rows after processing global buffer
# Buffered row (total: 226 rows)
# [328.3s] Actual: 21.55, Predicted: 34.24
# No valid rows after processing global buffer
# Buffered row (total: 227 rows)
# [329.9s] Actual: 21.55, Predicted: 34.24
# No valid rows after processing global buffer
# Buffered row (total: 228 rows)
# [331.6s] Actual: 21.55, Predicted: 34.24
# Current RMSE: 7.0914
# No valid rows after processing global buffer
# Buffered row (total: 229 rows)
# [333.2s] Actual: 21.55, Predicted: 34.24
# No valid rows after processing global buffer
# Buffered row (total: 230 rows)
# [334.9s] Actual: 21.55, Predicted: 34.24
# No valid rows after processing global buffer
# Buffered row (total: 231 rows)
# [336.5s] Actual: 22.66, Predicted: 27.34
# No valid rows after processing global buffer
# Buffered row (total: 232 rows)
# [338.3s] Actual: 22.66, Predicted: 27.34
# No valid rows after processing global buffer
# Buffered row (total: 233 rows)
# [340.8s] Actual: 22.56, Predicted: 34.06
# No valid rows after processing global buffer
# Buffered row (total: 234 rows)
# [343.1s] Actual: 22.56, Predicted: 34.06
# No valid rows after processing global buffer
# Buffered row (total: 235 rows)
# [345.2s] Actual: 22.56, Predicted: 34.06
# No valid rows after processing global buffer
# Buffered row (total: 236 rows)
# [346.8s] Actual: 22.56, Predicted: 34.06
# No valid rows after processing global buffer
# Buffered row (total: 237 rows)
# [348.5s] Actual: 22.56, Predicted: 34.06
# No valid rows after processing global buffer
# Buffered row (total: 238 rows)
# [350.1s] Actual: 22.56, Predicted: 34.06
# Current RMSE: 7.4151
# No valid rows after processing global buffer
# Buffered row (total: 239 rows)
# [351.7s] Actual: 22.56, Predicted: 34.06
# No valid rows after processing global buffer
# Buffered row (total: 240 rows)
# [353.9s] Actual: 22.56, Predicted: 34.06
# No valid rows after processing global buffer
# Buffered row (total: 241 rows)
# [356.6s] Actual: 22.65, Predicted: 30.79
# No valid rows after processing global buffer
# Buffered row (total: 242 rows)
# [358.5s] Actual: 22.65, Predicted: 30.79
# No valid rows after processing global buffer
# Buffered row (total: 243 rows)
# [360.3s] Actual: 22.65, Predicted: 30.79
# No valid rows after processing global buffer
# Buffered row (total: 244 rows)
# [361.9s] Actual: 22.65, Predicted: 30.79
# No valid rows after processing global buffer
# Buffered row (total: 245 rows)
# [363.6s] Actual: 23.47, Predicted: 31.21
# No valid rows after processing global buffer
# Buffered row (total: 246 rows)
# [365.3s] Actual: 23.47, Predicted: 31.21
# No valid rows after processing global buffer
# Buffered row (total: 247 rows)
# [366.9s] Actual: 23.47, Predicted: 31.21
# No valid rows after processing global buffer
# Buffered row (total: 248 rows)
# [369.4s] Actual: 23.47, Predicted: 31.21
# Current RMSE: 7.5131
# No valid rows after processing global buffer
# Buffered row (total: 249 rows)
# [371.9s] Actual: 23.47, Predicted: 31.21
# No valid rows after processing global buffer
# Buffered row (total: 250 rows)
# [373.6s] Actual: 21.69, Predicted: 34.90
# No valid rows after processing global buffer
# Buffered row (total: 251 rows)
# [375.4s] Actual: 21.69, Predicted: 34.90
# No valid rows after processing global buffer
# Buffered row (total: 252 rows)
# [377.1s] Actual: 21.69, Predicted: 34.90
# No valid rows after processing global buffer
# Buffered row (total: 253 rows)
# [378.8s] Actual: 21.69, Predicted: 34.90
# No valid rows after processing global buffer
# Buffered row (total: 254 rows)
# [380.4s] Actual: 21.69, Predicted: 34.90
# No valid rows after processing global buffer
# Buffered row (total: 255 rows)
# [382.3s] Actual: 23.84, Predicted: 34.46
# No valid rows after processing global buffer
# Buffered row (total: 256 rows)
# [385.3s] Actual: 23.84, Predicted: 34.46
# No valid rows after processing global buffer
# Buffered row (total: 257 rows)
# [387.9s] Actual: 23.84, Predicted: 34.46
# No valid rows after processing global buffer
# Buffered row (total: 258 rows)
# [389.5s] Actual: 23.84, Predicted: 34.46
# Current RMSE: 7.8466
# No valid rows after processing global buffer
# Buffered row (total: 259 rows)
# [391.2s] Actual: 23.84, Predicted: 34.46
# No valid rows after processing global buffer
# Buffered row (total: 260 rows)
# [392.8s] Actual: 23.84, Predicted: 34.46
# No valid rows after processing global buffer
# Buffered row (total: 261 rows)
# [394.5s] Actual: 25.96, Predicted: 36.88
# No valid rows after processing global buffer
# Buffered row (total: 262 rows)
# [396.1s] Actual: 25.96, Predicted: 36.88
# No valid rows after processing global buffer
# Buffered row (total: 263 rows)
# [398.4s] Actual: 25.96, Predicted: 36.88
# No valid rows after processing global buffer
# Buffered row (total: 264 rows)
# [401.0s] Actual: 25.96, Predicted: 36.88
# No valid rows after processing global buffer
# Buffered row (total: 265 rows)
# [402.8s] Actual: 26.54, Predicted: 42.93
# No valid rows after processing global buffer
# Buffered row (total: 266 rows)
# [404.5s] Actual: 26.54, Predicted: 42.93
# No valid rows after processing global buffer
# Buffered row (total: 267 rows)
# [406.1s] Actual: 26.54, Predicted: 42.93
# No valid rows after processing global buffer
# Buffered row (total: 268 rows)
# [407.8s] Actual: 24.95, Predicted: 36.09
# Current RMSE: 8.2191
# No valid rows after processing global buffer
# Buffered row (total: 269 rows)
# [409.4s] Actual: 24.95, Predicted: 36.09
# No valid rows after processing global buffer
# Buffered row (total: 270 rows)
# [411.0s] Actual: 24.95, Predicted: 36.09
# No valid rows after processing global buffer
# Buffered row (total: 271 rows)
# [413.6s] Actual: 24.95, Predicted: 36.09
# No valid rows after processing global buffer
# Buffered row (total: 272 rows)
# [415.9s] Actual: 24.95, Predicted: 36.09
# No valid rows after processing global buffer
# Buffered row (total: 273 rows)
# [417.6s] Actual: 25.11, Predicted: 35.44
# No valid rows after processing global buffer
# Buffered row (total: 274 rows)
# [419.2s] Actual: 25.11, Predicted: 35.44
# No valid rows after processing global buffer
# Buffered row (total: 275 rows)
# [420.9s] Actual: 25.11, Predicted: 35.44
# No valid rows after processing global buffer
# Buffered row (total: 276 rows)
# [422.5s] Actual: 25.11, Predicted: 35.44
# No valid rows after processing global buffer
# Buffered row (total: 277 rows)
# [424.2s] Actual: 25.11, Predicted: 35.44
# No valid rows after processing global buffer
# Buffered row (total: 278 rows)
# [425.9s] Actual: 25.11, Predicted: 35.44
# Current RMSE: 8.3737
# No valid rows after processing global buffer
# Buffered row (total: 279 rows)
# [428.4s] Actual: 26.04, Predicted: 35.62
# No valid rows after processing global buffer
# Buffered row (total: 280 rows)
# [430.7s] Actual: 26.04, Predicted: 35.62
# No valid rows after processing global buffer
# Buffered row (total: 281 rows)
# [432.3s] Actual: 26.04, Predicted: 35.62
# No valid rows after processing global buffer
# Buffered row (total: 282 rows)
# [434.0s] Actual: 26.04, Predicted: 35.62
# No valid rows after processing global buffer
# Buffered row (total: 283 rows)
# [435.7s] Actual: 26.04, Predicted: 35.62
# No valid rows after processing global buffer
# Buffered row (total: 284 rows)
# [437.3s] Actual: 26.04, Predicted: 35.62
# No valid rows after processing global buffer
# Buffered row (total: 285 rows)
# [440.0s] Actual: 27.36, Predicted: 32.39
# No valid rows after processing global buffer
# Buffered row (total: 286 rows)
# [444.2s] Actual: 27.36, Predicted: 32.39
# No valid rows after processing global buffer
# Buffered row (total: 287 rows)
# [446.2s] Actual: 27.36, Predicted: 32.39
# No valid rows after processing global buffer
# Buffered row (total: 288 rows)
# [447.9s] Actual: 27.36, Predicted: 32.39
# Current RMSE: 8.3582
# No valid rows after processing global buffer
# Buffered row (total: 289 rows)
# [449.5s] Actual: 27.36, Predicted: 32.39
# No valid rows after processing global buffer
# Buffered row (total: 290 rows)
# [451.2s] Actual: 27.36, Predicted: 32.39
# No valid rows after processing global buffer
# Buffered row (total: 291 rows)
# [452.9s] Actual: 26.76, Predicted: 38.24
# No valid rows after processing global buffer
# Buffered row (total: 292 rows)
# [454.6s] Actual: 26.76, Predicted: 38.24
# No valid rows after processing global buffer
# Buffered row (total: 293 rows)
# [457.2s] Actual: 24.24, Predicted: 30.18
# No valid rows after processing global buffer
# Buffered row (total: 294 rows)
# [459.6s] Actual: 24.24, Predicted: 30.18
# No valid rows after processing global buffer
# Buffered row (total: 295 rows)
# [461.3s] Actual: 24.24, Predicted: 30.18
# No valid rows after processing global buffer
# Buffered row (total: 296 rows)
# [462.9s] Actual: 24.24, Predicted: 30.18
# No valid rows after processing global buffer
# Buffered row (total: 297 rows)
# [464.6s] Actual: 25.47, Predicted: 39.69
# No valid rows after processing global buffer
# Buffered row (total: 298 rows)
# [466.2s] Actual: 25.47, Predicted: 39.69
# Current RMSE: 8.4062
# No valid rows after processing global buffer
# Buffered row (total: 299 rows)
# [468.0s] Actual: 25.47, Predicted: 39.69
# No valid rows after processing global buffer
# Buffered row (total: 300 rows)
# [469.8s] Actual: 25.47, Predicted: 39.69
# No valid rows after processing global buffer
# Buffered row (total: 301 rows)
# [472.4s] Actual: 25.47, Predicted: 39.69
# No valid rows after processing global buffer
# Buffered row (total: 302 rows)
# [474.7s] Actual: 24.04, Predicted: 26.88
# No valid rows after processing global buffer
# Buffered row (total: 303 rows)
# [476.4s] Actual: 24.04, Predicted: 26.88
# No valid rows after processing global buffer
# Buffered row (total: 304 rows)
# [478.1s] Actual: 24.04, Predicted: 26.88
# No valid rows after processing global buffer
# Buffered row (total: 305 rows)
# [479.8s] Actual: 24.04, Predicted: 26.88
# No valid rows after processing global buffer
# Buffered row (total: 306 rows)
# [481.5s] Actual: 24.04, Predicted: 26.88
# No valid rows after processing global buffer
# Buffered row (total: 307 rows)
# [483.1s] Actual: 27.88, Predicted: 30.54
# No valid rows after processing global buffer
# Buffered row (total: 308 rows)
# [485.1s] Actual: 27.88, Predicted: 30.54
# Current RMSE: 8.3932
# No valid rows after processing global buffer
# Buffered row (total: 309 rows)
# [487.8s] Actual: 27.88, Predicted: 30.54
# No valid rows after processing global buffer
# Buffered row (total: 310 rows)
# [489.7s] Actual: 27.88, Predicted: 30.54
# No valid rows after processing global buffer
# Buffered row (total: 311 rows)
# [491.3s] Actual: 27.88, Predicted: 30.54
# No valid rows after processing global buffer
# Buffered row (total: 312 rows)
# [493.0s] Actual: 27.88, Predicted: 30.54
# No valid rows after processing global buffer
# Buffered row (total: 313 rows)
# [494.7s] Actual: 27.88, Predicted: 30.54
# No valid rows after processing global buffer
# Buffered row (total: 314 rows)
# [496.5s] Actual: 26.63, Predicted: 34.11
# No valid rows after processing global buffer
# Buffered row (total: 315 rows)
# [498.2s] Actual: 26.63, Predicted: 34.11
# No valid rows after processing global buffer
# Buffered row (total: 316 rows)
# [500.7s] Actual: 26.63, Predicted: 34.11
# No valid rows after processing global buffer
# Buffered row (total: 317 rows)
# [503.2s] Actual: 27.90, Predicted: 42.04
# No valid rows after processing global buffer
# Buffered row (total: 318 rows)
# [504.8s] Actual: 27.90, Predicted: 42.04
# Current RMSE: 8.3657
# No valid rows after processing global buffer
# Buffered row (total: 319 rows)
# [506.5s] Actual: 27.90, Predicted: 42.04
# No valid rows after processing global buffer
# Buffered row (total: 320 rows)
# [508.3s] Actual: 27.90, Predicted: 42.04
# No valid rows after processing global buffer
# Buffered row (total: 321 rows)
# [510.0s] Actual: 27.90, Predicted: 42.04
# No valid rows after processing global buffer
# Buffered row (total: 322 rows)
# [511.7s] Actual: 27.90, Predicted: 42.04
# No valid rows after processing global buffer
# Buffered row (total: 323 rows)
# [513.5s] Actual: 28.74, Predicted: 36.06
# No valid rows after processing global buffer
# Buffered row (total: 324 rows)
# [515.9s] Actual: 28.74, Predicted: 36.06
# No valid rows after processing global buffer
# Buffered row (total: 325 rows)
# [518.3s] Actual: 28.74, Predicted: 36.06
# No valid rows after processing global buffer
# Buffered row (total: 326 rows)
# [520.1s] Actual: 28.74, Predicted: 36.06
# No valid rows after processing global buffer
# Buffered row (total: 327 rows)
# [522.0s] Actual: 28.74, Predicted: 36.06
# No valid rows after processing global buffer
# Buffered row (total: 328 rows)
# [523.7s] Actual: 29.57, Predicted: 36.21
# Current RMSE: 8.4721
# No valid rows after processing global buffer
# Buffered row (total: 329 rows)
# [525.4s] Actual: 29.57, Predicted: 36.21
# No valid rows after processing global buffer
# Buffered row (total: 330 rows)
# [527.0s] Actual: 29.57, Predicted: 36.21
# No valid rows after processing global buffer
# Buffered row (total: 331 rows)
# [529.3s] Actual: 29.57, Predicted: 36.21
# No valid rows after processing global buffer
# Buffered row (total: 332 rows)
# [532.0s] Actual: 29.57, Predicted: 36.21
# No valid rows after processing global buffer
# Buffered row (total: 333 rows)
# [533.8s] Actual: 27.43, Predicted: 32.59
# No valid rows after processing global buffer
# Buffered row (total: 334 rows)
# [535.5s] Actual: 27.43, Predicted: 32.59
# No valid rows after processing global buffer
# Buffered row (total: 335 rows)
# [537.2s] Actual: 27.43, Predicted: 32.59
# No valid rows after processing global buffer
# Buffered row (total: 336 rows)
# [538.9s] Actual: 27.43, Predicted: 32.59
# No valid rows after processing global buffer
# Buffered row (total: 337 rows)
# [540.5s] Actual: 27.43, Predicted: 32.59
# No valid rows after processing global buffer
# Buffered row (total: 338 rows)
# [542.2s] Actual: 27.43, Predicted: 32.59
# Current RMSE: 8.3778
# No valid rows after processing global buffer
# Buffered row (total: 339 rows)
# [544.7s] Actual: 27.43, Predicted: 32.59
# No valid rows after processing global buffer
# Buffered row (total: 340 rows)
# [547.2s] Actual: 27.43, Predicted: 32.59
# No valid rows after processing global buffer
# Buffered row (total: 341 rows)
# [548.9s] Actual: 35.15, Predicted: 37.87
# No valid rows after processing global buffer
# Buffered row (total: 342 rows)
# [550.6s] Actual: 35.15, Predicted: 37.87
# No valid rows after processing global buffer
# Buffered row (total: 343 rows)
# [552.3s] Actual: 35.15, Predicted: 37.87
# No valid rows after processing global buffer
# Buffered row (total: 344 rows)
# [553.9s] Actual: 35.15, Predicted: 37.87
# No valid rows after processing global buffer
# Buffered row (total: 345 rows)
# [555.6s] Actual: 35.15, Predicted: 37.87
# No valid rows after processing global buffer
# Buffered row (total: 346 rows)
# [557.2s] Actual: 35.15, Predicted: 37.87
# No valid rows after processing global buffer
# Buffered row (total: 347 rows)
# [559.8s] Actual: 36.39, Predicted: 43.24
# No valid rows after processing global buffer
# Buffered row (total: 348 rows)
# [562.2s] Actual: 36.39, Predicted: 43.24
# Current RMSE: 8.2550
# No valid rows after processing global buffer
# Buffered row (total: 349 rows)
# [563.9s] Actual: 36.39, Predicted: 43.24
# No valid rows after processing global buffer
# Buffered row (total: 350 rows)
# [565.5s] Actual: 36.39, Predicted: 43.24
# No valid rows after processing global buffer
# Buffered row (total: 351 rows)
# [567.2s] Actual: 36.39, Predicted: 43.24
# No valid rows after processing global buffer
# Buffered row (total: 352 rows)
# [568.8s] Actual: 34.41, Predicted: 30.65
# No valid rows after processing global buffer
# Buffered row (total: 353 rows)
# [570.4s] Actual: 26.08, Predicted: 40.56
# No valid rows after processing global buffer
# Buffered row (total: 354 rows)
# [572.3s] Actual: 26.08, Predicted: 40.56
# No valid rows after processing global buffer
# Buffered row (total: 355 rows)
# [574.9s] Actual: 26.08, Predicted: 40.56
# No valid rows after processing global buffer
# Buffered row (total: 356 rows)
# [577.0s] Actual: 26.08, Predicted: 40.56
# No valid rows after processing global buffer
# Buffered row (total: 357 rows)
# [578.6s] Actual: 26.08, Predicted: 40.56
# No valid rows after processing global buffer
# Buffered row (total: 358 rows)
# [580.3s] Actual: 26.08, Predicted: 40.56
# Current RMSE: 8.4237
# No valid rows after processing global buffer
# Buffered row (total: 359 rows)
# [581.9s] Actual: 26.08, Predicted: 40.56
# No valid rows after processing global buffer
# Buffered row (total: 360 rows)
# [583.6s] Actual: 34.90, Predicted: 38.05
# No valid rows after processing global buffer
# Buffered row (total: 361 rows)
# [585.2s] Actual: 34.90, Predicted: 38.05
# No valid rows after processing global buffer
# Buffered row (total: 362 rows)
# [587.4s] Actual: 34.90, Predicted: 38.05
# No valid rows after processing global buffer
# Buffered row (total: 363 rows)
# [590.0s] Actual: 34.90, Predicted: 38.05
# No valid rows after processing global buffer
# Buffered row (total: 364 rows)
# [591.8s] Actual: 34.90, Predicted: 38.05
# No valid rows after processing global buffer
# Buffered row (total: 365 rows)
# [593.5s] Actual: 35.72, Predicted: 45.20
# No valid rows after processing global buffer
# Buffered row (total: 366 rows)
# [595.1s] Actual: 35.36, Predicted: 53.56
# No valid rows after processing global buffer
# Buffered row (total: 367 rows)
# [596.8s] Actual: 35.36, Predicted: 53.56
# No valid rows after processing global buffer
# Buffered row (total: 368 rows)
# [598.5s] Actual: 35.36, Predicted: 53.56
# Current RMSE: 8.5617
# No valid rows after processing global buffer
# Buffered row (total: 369 rows)
# [600.1s] Actual: 35.36, Predicted: 53.56
# No valid rows after processing global buffer
# Buffered row (total: 370 rows)
# [602.6s] Actual: 45.85, Predicted: 31.60
# No valid rows after processing global buffer
# Buffered row (total: 371 rows)
# [605.1s] Actual: 45.85, Predicted: 31.60
# No valid rows after processing global buffer
# Buffered row (total: 372 rows)
# [606.7s] Actual: 45.85, Predicted: 31.60
# No valid rows after processing global buffer
# Buffered row (total: 373 rows)
# [608.4s] Actual: 45.85, Predicted: 31.60
# No valid rows after processing global buffer
# Buffered row (total: 374 rows)
# [610.0s] Actual: 45.81, Predicted: 35.12
# No valid rows after processing global buffer
# Buffered row (total: 375 rows)
# [611.7s] Actual: 45.81, Predicted: 35.12
# No valid rows after processing global buffer
# Buffered row (total: 376 rows)
# [613.3s] Actual: 45.81, Predicted: 35.12
# No valid rows after processing global buffer
# Buffered row (total: 377 rows)
# [615.0s] Actual: 45.81, Predicted: 35.12
# No valid rows after processing global buffer
# Buffered row (total: 378 rows)
# [617.6s] Actual: 45.81, Predicted: 35.12
# Current RMSE: 8.7643
# No valid rows after processing global buffer
# Buffered row (total: 379 rows)
# [619.9s] Actual: 45.81, Predicted: 35.12
# No valid rows after processing global buffer
# Buffered row (total: 380 rows)
# [621.6s] Actual: 45.81, Predicted: 35.12
# No valid rows after processing global buffer
# Buffered row (total: 381 rows)
# [623.3s] Actual: 47.46, Predicted: 52.54
# No valid rows after processing global buffer
# Buffered row (total: 382 rows)
# [625.0s] Actual: 47.46, Predicted: 52.54
# No valid rows after processing global buffer
# Buffered row (total: 383 rows)
# [626.6s] Actual: 47.46, Predicted: 52.54
# No valid rows after processing global buffer
# Buffered row (total: 384 rows)
# [628.4s] Actual: 38.76, Predicted: 31.54
# No valid rows after processing global buffer
# Buffered row (total: 385 rows)
# [630.4s] Actual: 38.76, Predicted: 31.54
# No valid rows after processing global buffer
# Buffered row (total: 386 rows)
# [633.0s] Actual: 38.76, Predicted: 31.54
# No valid rows after processing global buffer
# Buffered row (total: 387 rows)
# [635.0s] Actual: 38.76, Predicted: 31.54
# No valid rows after processing global buffer
# Buffered row (total: 388 rows)
# [636.7s] Actual: 38.76, Predicted: 31.54
# Current RMSE: 8.7245
# No valid rows after processing global buffer
# Buffered row (total: 389 rows)
# [638.3s] Actual: 37.13, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 390 rows)
# [640.0s] Actual: 37.13, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 391 rows)
# [641.6s] Actual: 37.13, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 392 rows)
# [643.3s] Actual: 37.13, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 393 rows)
# [645.6s] Actual: 37.13, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 394 rows)
# [648.7s] Actual: 35.96, Predicted: 39.24
# No valid rows after processing global buffer
# Buffered row (total: 395 rows)
# [650.3s] Actual: 35.96, Predicted: 39.24
# No valid rows after processing global buffer
# Buffered row (total: 396 rows)
# [652.0s] Actual: 35.96, Predicted: 39.24
# No valid rows after processing global buffer
# Buffered row (total: 397 rows)
# [653.6s] Actual: 35.96, Predicted: 39.24
# No valid rows after processing global buffer
# Buffered row (total: 398 rows)
# [655.3s] Actual: 35.96, Predicted: 39.24
# Current RMSE: 8.6117
# No valid rows after processing global buffer
# Buffered row (total: 399 rows)
# [656.9s] Actual: 37.81, Predicted: 35.97
# No valid rows after processing global buffer
# Buffered row (total: 400 rows)
# [658.8s] Actual: 37.81, Predicted: 35.97
# No valid rows after processing global buffer
# Buffered row (total: 401 rows)
# [661.3s] Actual: 37.81, Predicted: 35.97
# No valid rows after processing global buffer
# Buffered row (total: 402 rows)
# [663.6s] Actual: 37.87, Predicted: 44.93
# No valid rows after processing global buffer
# Buffered row (total: 403 rows)
# [665.2s] Actual: 37.87, Predicted: 44.93
# No valid rows after processing global buffer
# Buffered row (total: 404 rows)
# [666.9s] Actual: 37.87, Predicted: 44.93
# No valid rows after processing global buffer
# Buffered row (total: 405 rows)
# [668.5s] Actual: 37.87, Predicted: 44.93
# No valid rows after processing global buffer
# Buffered row (total: 406 rows)
# [670.2s] Actual: 37.87, Predicted: 44.93
# No valid rows after processing global buffer
# Buffered row (total: 407 rows)
# [671.8s] Actual: 37.77, Predicted: 46.27
# No valid rows after processing global buffer
# Buffered row (total: 408 rows)
# [673.9s] Actual: 37.77, Predicted: 46.27
# Current RMSE: 8.5482
# No valid rows after processing global buffer
# Buffered row (total: 409 rows)
# [676.5s] Actual: 37.77, Predicted: 46.27
# No valid rows after processing global buffer
# Buffered row (total: 410 rows)
# [678.5s] Actual: 32.12, Predicted: 36.42
# No valid rows after processing global buffer
# Buffered row (total: 411 rows)
# [680.3s] Actual: 32.12, Predicted: 36.42
# No valid rows after processing global buffer
# Buffered row (total: 412 rows)
# [682.1s] Actual: 32.12, Predicted: 36.42
# No valid rows after processing global buffer
# Buffered row (total: 413 rows)
# [683.6s] Actual: 32.05, Predicted: 45.82
# No valid rows after processing global buffer
# Buffered row (total: 414 rows)
# [685.4s] Actual: 32.05, Predicted: 45.82
# No valid rows after processing global buffer
# Buffered row (total: 415 rows)
# [687.2s] Actual: 32.05, Predicted: 45.82
# No valid rows after processing global buffer
# Buffered row (total: 416 rows)
# [689.7s] Actual: 37.37, Predicted: 41.82
# No valid rows after processing global buffer
# Buffered row (total: 417 rows)
# [692.4s] Actual: 37.37, Predicted: 41.82
# No valid rows after processing global buffer
# Buffered row (total: 418 rows)
# [694.1s] Actual: 37.37, Predicted: 41.82
# Current RMSE: 8.5529
# No valid rows after processing global buffer
# Buffered row (total: 419 rows)
# [695.7s] Actual: 37.37, Predicted: 41.82
# No valid rows after processing global buffer
# Buffered row (total: 420 rows)
# [697.3s] Actual: 37.37, Predicted: 41.82
# No valid rows after processing global buffer
# Buffered row (total: 421 rows)
# [699.1s] Actual: 36.56, Predicted: 40.46
# No valid rows after processing global buffer
# Buffered row (total: 422 rows)
# [700.7s] Actual: 36.56, Predicted: 40.46
# No valid rows after processing global buffer
# Buffered row (total: 423 rows)
# [702.6s] Actual: 36.56, Predicted: 40.46
# No valid rows after processing global buffer
# Buffered row (total: 424 rows)
# [705.0s] Actual: 34.72, Predicted: 33.23
# No valid rows after processing global buffer
# Buffered row (total: 425 rows)
# [707.2s] Actual: 34.72, Predicted: 33.23
# No valid rows after processing global buffer
# Buffered row (total: 426 rows)
# [708.9s] Actual: 34.72, Predicted: 33.23
# No valid rows after processing global buffer
# Buffered row (total: 427 rows)
# [711.0s] Actual: 34.72, Predicted: 33.23
# No valid rows after processing global buffer
# Buffered row (total: 428 rows)
# [712.7s] Actual: 36.61, Predicted: 42.05
# Current RMSE: 8.4446
# No valid rows after processing global buffer
# Buffered row (total: 429 rows)
# [714.3s] Actual: 36.61, Predicted: 42.05
# No valid rows after processing global buffer
# Buffered row (total: 430 rows)
# [716.0s] Actual: 36.61, Predicted: 42.05
# No valid rows after processing global buffer
# Buffered row (total: 431 rows)
# [718.1s] Actual: 36.61, Predicted: 42.05
# No valid rows after processing global buffer
# Buffered row (total: 432 rows)
# [720.6s] Actual: 36.61, Predicted: 42.05
# No valid rows after processing global buffer
# Buffered row (total: 433 rows)
# [722.5s] Actual: 36.61, Predicted: 42.05
# No valid rows after processing global buffer
# Buffered row (total: 434 rows)
# [724.2s] Actual: 36.61, Predicted: 42.05
# No valid rows after processing global buffer
# Buffered row (total: 435 rows)
# [725.9s] Actual: 26.07, Predicted: 37.68
# No valid rows after processing global buffer
# Buffered row (total: 436 rows)
# [727.5s] Actual: 26.07, Predicted: 37.68
# No valid rows after processing global buffer
# Buffered row (total: 437 rows)
# [729.2s] Actual: 26.07, Predicted: 37.68
# No valid rows after processing global buffer
# Buffered row (total: 438 rows)
# [730.8s] Actual: 23.35, Predicted: 27.37
# Current RMSE: 8.4244
# No valid rows after processing global buffer
# Buffered row (total: 439 rows)
# [733.0s] Actual: 23.35, Predicted: 27.37
# No valid rows after processing global buffer
# Buffered row (total: 440 rows)
# [735.7s] Actual: 23.35, Predicted: 27.37
# No valid rows after processing global buffer
# Buffered row (total: 441 rows)
# [737.4s] Actual: 23.35, Predicted: 27.37
# No valid rows after processing global buffer
# Buffered row (total: 442 rows)
# [739.0s] Actual: 23.09, Predicted: 22.06
# No valid rows after processing global buffer
# Buffered row (total: 443 rows)
# [740.7s] Actual: 23.09, Predicted: 22.06
# No valid rows after processing global buffer
# Buffered row (total: 444 rows)
# [742.3s] Actual: 35.60, Predicted: 24.21
# No valid rows after processing global buffer
# Buffered row (total: 445 rows)
# [744.0s] Actual: 35.60, Predicted: 24.21
# No valid rows after processing global buffer
# Buffered row (total: 446 rows)
# [745.6s] Actual: 33.17, Predicted: 30.97
# No valid rows after processing global buffer
# Buffered row (total: 447 rows)
# [748.1s] Actual: 33.17, Predicted: 30.97
# No valid rows after processing global buffer
# Buffered row (total: 448 rows)
# [750.7s] Actual: 33.17, Predicted: 30.97
# Current RMSE: 8.3589
# No valid rows after processing global buffer
# Buffered row (total: 449 rows)
# [752.4s] Actual: 33.17, Predicted: 30.97
# No valid rows after processing global buffer
# Buffered row (total: 450 rows)
# [754.5s] Actual: 33.17, Predicted: 30.97
# No valid rows after processing global buffer
# Buffered row (total: 451 rows)
# [756.2s] Actual: 33.17, Predicted: 30.97
# No valid rows after processing global buffer
# Buffered row (total: 452 rows)
# [757.8s] Actual: 33.17, Predicted: 30.97
# No valid rows after processing global buffer
# Buffered row (total: 453 rows)
# [759.5s] Actual: 36.31, Predicted: 39.94
# No valid rows after processing global buffer
# Buffered row (total: 454 rows)
# [761.5s] Actual: 36.31, Predicted: 39.94
# No valid rows after processing global buffer
# Buffered row (total: 455 rows)
# [764.2s] Actual: 36.31, Predicted: 39.94
# No valid rows after processing global buffer
# Buffered row (total: 456 rows)
# [766.1s] Actual: 36.31, Predicted: 39.94
# No valid rows after processing global buffer
# Buffered row (total: 457 rows)
# [767.9s] Actual: 36.31, Predicted: 39.94
# No valid rows after processing global buffer
# Buffered row (total: 458 rows)
# [769.7s] Actual: 36.31, Predicted: 39.94
# Current RMSE: 8.2585
# No valid rows after processing global buffer
# Buffered row (total: 459 rows)
# [771.4s] Actual: 27.67, Predicted: 21.41
# No valid rows after processing global buffer
# Buffered row (total: 460 rows)
# [773.0s] Actual: 24.51, Predicted: 25.72
# No valid rows after processing global buffer
# Buffered row (total: 461 rows)
# [774.7s] Actual: 24.51, Predicted: 25.72
# No valid rows after processing global buffer
# Buffered row (total: 462 rows)
# [777.6s] Actual: 27.03, Predicted: 39.48
# No valid rows after processing global buffer
# Buffered row (total: 463 rows)
# [780.0s] Actual: 27.03, Predicted: 39.48
# No valid rows after processing global buffer
# Buffered row (total: 464 rows)
# [781.6s] Actual: 27.03, Predicted: 39.48
# No valid rows after processing global buffer
# Buffered row (total: 465 rows)
# [783.3s] Actual: 27.03, Predicted: 39.48
# No valid rows after processing global buffer
# Buffered row (total: 466 rows)
# [785.0s] Actual: 26.75, Predicted: 40.27
# No valid rows after processing global buffer
# Buffered row (total: 467 rows)
# [786.6s] Actual: 26.75, Predicted: 40.27
# No valid rows after processing global buffer
# Buffered row (total: 468 rows)
# [788.3s] Actual: 26.75, Predicted: 40.27
# Current RMSE: 8.3445
# No valid rows after processing global buffer
# Buffered row (total: 469 rows)
# [790.0s] Actual: 26.75, Predicted: 40.27
# No valid rows after processing global buffer
# Buffered row (total: 470 rows)
# [792.6s] Actual: 27.46, Predicted: 36.48
# No valid rows after processing global buffer
# Buffered row (total: 471 rows)
# [794.8s] Actual: 27.46, Predicted: 36.48
# No valid rows after processing global buffer
# Buffered row (total: 472 rows)
# [796.5s] Actual: 27.46, Predicted: 36.48
# No valid rows after processing global buffer
# Buffered row (total: 473 rows)
# [798.2s] Actual: 27.46, Predicted: 36.48
# No valid rows after processing global buffer
# Buffered row (total: 474 rows)
# [799.9s] Actual: 27.46, Predicted: 36.48
# No valid rows after processing global buffer
# Buffered row (total: 475 rows)
# [801.6s] Actual: 27.46, Predicted: 36.48
# No valid rows after processing global buffer
# Buffered row (total: 476 rows)
# [803.4s] Actual: 24.85, Predicted: 33.57
# No valid rows after processing global buffer
# Buffered row (total: 477 rows)
# [805.6s] Actual: 24.85, Predicted: 33.57
# No valid rows after processing global buffer
# Buffered row (total: 478 rows)
# ...
# No valid rows after processing global buffer
# Buffered row (total: 561 rows)
# [964.3s] Actual: 24.00, Predicted: 22.93
# No valid rows after processing global buffer
# Buffered row (total: 562 rows)
# [966.8s] Actual: 24.49, Predicted: 40.89
# No valid rows after processing global buffer
# Buffered row (total: 563 rows)
# [969.1s] Actual: 24.49, Predicted: 40.89
# No valid rows after processing global buffer
# Buffered row (total: 564 rows)
# [970.8s] Actual: 24.49, Predicted: 40.89
# No valid rows after processing global buffer
# Buffered row (total: 565 rows)
# [972.4s] Actual: 24.49, Predicted: 40.89
# No valid rows after processing global buffer
# Buffered row (total: 566 rows)
# [974.1s] Actual: 22.89, Predicted: 32.13
# No valid rows after processing global buffer
# Buffered row (total: 567 rows)
# [975.7s] Actual: 22.89, Predicted: 32.13
# No valid rows after processing global buffer
# Buffered row (total: 568 rows)
# [977.4s] Actual: 22.89, Predicted: 32.13
# Current RMSE: 9.1159
# No valid rows after processing global buffer
# Buffered row (total: 569 rows)
# [979.2s] Actual: 22.89, Predicted: 32.13
# No valid rows after processing global buffer
# Buffered row (total: 570 rows)
# [981.7s] Actual: 22.89, Predicted: 32.13
# No valid rows after processing global buffer
# Buffered row (total: 571 rows)
# [983.9s] Actual: 22.79, Predicted: 32.27
# No valid rows after processing global buffer
# Buffered row (total: 572 rows)
# [985.6s] Actual: 22.79, Predicted: 32.27
# No valid rows after processing global buffer
# Buffered row (total: 573 rows)
# [987.2s] Actual: 22.79, Predicted: 32.27
# WARNING:kafka.coordinator:Heartbeat poll expired, leaving group
# ERROR:kafka.coordinator:Heartbeat thread for group CONSUMER_GROUP_ID failed due to unexpected error: cannot release un-acquired lock
# No valid rows after processing global buffer
# Buffered row (total: 574 rows)
# [988.9s] Actual: 24.18, Predicted: 28.35
# No valid rows after processing global buffer
# Buffered row (total: 575 rows)
# [990.6s] Actual: 24.18, Predicted: 28.35
# No valid rows after processing global buffer
# Buffered row (total: 576 rows)
# [992.2s] Actual: 24.18, Predicted: 28.35
# No valid rows after processing global buffer
# Buffered row (total: 577 rows)
# [994.1s] Actual: 24.18, Predicted: 28.35
# No valid rows after processing global buffer
# Buffered row (total: 578 rows)
# [996.9s] Actual: 26.40, Predicted: 41.22
# Current RMSE: 9.1043
# No valid rows after processing global buffer
# Buffered row (total: 579 rows)
# [998.9s] Actual: 26.40, Predicted: 41.22
# No valid rows after processing global buffer
# Buffered row (total: 580 rows)
# [1000.5s] Actual: 25.87, Predicted: 35.29
# No valid rows after processing global buffer
# Buffered row (total: 581 rows)
# [1002.1s] Actual: 25.87, Predicted: 35.29
# No valid rows after processing global buffer
# Buffered row (total: 582 rows)
# [1003.7s] Actual: 25.87, Predicted: 35.29
# No valid rows after processing global buffer
# Buffered row (total: 583 rows)
# [1005.4s] Actual: 25.87, Predicted: 35.29
# No valid rows after processing global buffer
# Buffered row (total: 584 rows)
# [1007.1s] Actual: 25.87, Predicted: 35.29
# No valid rows after processing global buffer
# Buffered row (total: 585 rows)
# [1009.5s] Actual: 26.11, Predicted: 41.71
# No valid rows after processing global buffer
# Buffered row (total: 586 rows)
# [1012.1s] Actual: 26.11, Predicted: 41.71
# No valid rows after processing global buffer
# Buffered row (total: 587 rows)
# [1013.8s] Actual: 26.11, Predicted: 41.71
# No valid rows after processing global buffer
# Buffered row (total: 588 rows)
# [1015.5s] Actual: 26.11, Predicted: 41.71
# Current RMSE: 9.1945
# No valid rows after processing global buffer
# Buffered row (total: 589 rows)
# [1017.2s] Actual: 26.11, Predicted: 41.71
# No valid rows after processing global buffer
# Buffered row (total: 590 rows)
# [1018.9s] Actual: 25.26, Predicted: 39.42
# No valid rows after processing global buffer
# Buffered row (total: 591 rows)
# [1020.5s] Actual: 25.26, Predicted: 39.42
# No valid rows after processing global buffer
# Buffered row (total: 592 rows)
# [1022.2s] Actual: 25.26, Predicted: 39.42
# No valid rows after processing global buffer
# Buffered row (total: 593 rows)
# [1024.9s] Actual: 25.26, Predicted: 39.42
# No valid rows after processing global buffer
# Buffered row (total: 594 rows)
# [1027.1s] Actual: 25.26, Predicted: 39.42
# No valid rows after processing global buffer
# Buffered row (total: 595 rows)
# [1028.7s] Actual: 25.26, Predicted: 39.42
# No valid rows after processing global buffer
# Buffered row (total: 596 rows)
# [1030.5s] Actual: 24.07, Predicted: 36.14
# No valid rows after processing global buffer
# Buffered row (total: 597 rows)
# [1032.1s] Actual: 24.07, Predicted: 36.14
# No valid rows after processing global buffer
# Buffered row (total: 598 rows)
# [1033.8s] Actual: 24.07, Predicted: 36.14
# Current RMSE: 9.3067
# No valid rows after processing global buffer
# Buffered row (total: 599 rows)
# [1035.4s] Actual: 24.07, Predicted: 36.14
# No valid rows after processing global buffer
# Buffered row (total: 600 rows)
# [1037.3s] Actual: 24.07, Predicted: 36.14
# No valid rows after processing global buffer
# Buffered row (total: 601 rows)
# [1039.9s] Actual: 24.07, Predicted: 36.14
# No valid rows after processing global buffer
# Buffered row (total: 602 rows)
# [1042.0s] Actual: 24.07, Predicted: 36.14
# No valid rows after processing global buffer
# Buffered row (total: 603 rows)
# [1043.6s] Actual: 24.16, Predicted: 32.24
# No valid rows after processing global buffer
# Buffered row (total: 604 rows)
# [1045.3s] Actual: 24.16, Predicted: 32.24
# No valid rows after processing global buffer
# Buffered row (total: 605 rows)
# [1046.9s] Actual: 24.16, Predicted: 32.24
# No valid rows after processing global buffer
# Buffered row (total: 606 rows)
# [1048.6s] Actual: 24.16, Predicted: 32.24
# No valid rows after processing global buffer
# Buffered row (total: 607 rows)
# [1050.2s] Actual: 24.16, Predicted: 32.24
# No valid rows after processing global buffer
# Buffered row (total: 608 rows)
# [1052.3s] Actual: 24.16, Predicted: 32.24
# Current RMSE: 9.3180
# No valid rows after processing global buffer
# Buffered row (total: 609 rows)
# [1054.9s] Actual: 28.69, Predicted: 45.01
# No valid rows after processing global buffer
# Buffered row (total: 610 rows)
# [1056.9s] Actual: 28.69, Predicted: 45.01
# No valid rows after processing global buffer
# Buffered row (total: 611 rows)
# [1058.6s] Actual: 28.69, Predicted: 45.01
# No valid rows after processing global buffer
# Buffered row (total: 612 rows)
# [1060.4s] Actual: 36.49, Predicted: 40.81
# No valid rows after processing global buffer
# Buffered row (total: 613 rows)
# [1062.1s] Actual: 36.49, Predicted: 40.81
# No valid rows after processing global buffer
# Buffered row (total: 614 rows)
# [1063.7s] Actual: 36.49, Predicted: 40.81
# No valid rows after processing global buffer
# Buffered row (total: 615 rows)
# [1065.4s] Actual: 36.49, Predicted: 40.81
# No valid rows after processing global buffer
# Buffered row (total: 616 rows)
# [1067.9s] Actual: 36.49, Predicted: 40.81
# No valid rows after processing global buffer
# Buffered row (total: 617 rows)
# [1070.3s] Actual: 40.32, Predicted: 37.55
# No valid rows after processing global buffer
# Buffered row (total: 618 rows)
# [1072.0s] Actual: 40.32, Predicted: 37.55
# Current RMSE: 9.3221
# No valid rows after processing global buffer
# Buffered row (total: 619 rows)
# [1073.7s] Actual: 40.32, Predicted: 37.55
# No valid rows after processing global buffer
# Buffered row (total: 620 rows)
# [1075.3s] Actual: 41.17, Predicted: 53.99
# No valid rows after processing global buffer
# Buffered row (total: 621 rows)
# [1077.0s] Actual: 41.17, Predicted: 53.99
# No valid rows after processing global buffer
# Buffered row (total: 622 rows)
# [1078.6s] Actual: 41.17, Predicted: 53.99
# No valid rows after processing global buffer
# Buffered row (total: 623 rows)
# [1080.4s] Actual: 43.29, Predicted: 44.21
# No valid rows after processing global buffer
# Buffered row (total: 624 rows)
# [1083.1s] Actual: 43.29, Predicted: 44.21
# No valid rows after processing global buffer
# Buffered row (total: 625 rows)
# [1085.3s] Actual: 43.29, Predicted: 44.21
# No valid rows after processing global buffer
# Buffered row (total: 626 rows)
# [1086.9s] Actual: 43.29, Predicted: 44.21
# No valid rows after processing global buffer
# Buffered row (total: 627 rows)
# [1088.5s] Actual: 43.29, Predicted: 44.21
# No valid rows after processing global buffer
# Buffered row (total: 628 rows)
# [1090.1s] Actual: 36.56, Predicted: 38.52
# Current RMSE: 9.2856
# No valid rows after processing global buffer
# Buffered row (total: 629 rows)
# [1091.8s] Actual: 36.56, Predicted: 38.52
# No valid rows after processing global buffer
# Buffered row (total: 630 rows)
# [1093.4s] Actual: 36.56, Predicted: 38.52
# No valid rows after processing global buffer
# Buffered row (total: 631 rows)
# [1095.3s] Actual: 36.56, Predicted: 38.52
# No valid rows after processing global buffer
# Buffered row (total: 632 rows)
# [1097.9s] Actual: 36.58, Predicted: 42.68
# No valid rows after processing global buffer
# Buffered row (total: 633 rows)
# [1100.0s] Actual: 36.58, Predicted: 42.68
# No valid rows after processing global buffer
# Buffered row (total: 634 rows)
# [1101.6s] Actual: 34.32, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 635 rows)
# [1103.3s] Actual: 34.32, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 636 rows)
# [1104.9s] Actual: 34.32, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 637 rows)
# [1106.5s] Actual: 34.32, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 638 rows)
# [1108.1s] Actual: 34.32, Predicted: 32.21
# Current RMSE: 9.2101
# No valid rows after processing global buffer
# Buffered row (total: 639 rows)
# [1110.2s] Actual: 34.32, Predicted: 32.21
# No valid rows after processing global buffer
# Buffered row (total: 640 rows)
# [1112.9s] Actual: 36.29, Predicted: 39.55
# No valid rows after processing global buffer
# Buffered row (total: 641 rows)
# [1114.8s] Actual: 36.29, Predicted: 39.55
# No valid rows after processing global buffer
# Buffered row (total: 642 rows)
# [1116.4s] Actual: 36.29, Predicted: 39.55
# No valid rows after processing global buffer
# Buffered row (total: 643 rows)
# [1118.1s] Actual: 36.29, Predicted: 39.55
# No valid rows after processing global buffer
# Buffered row (total: 644 rows)
# [1119.7s] Actual: 36.29, Predicted: 39.55
# No valid rows after processing global buffer
# Buffered row (total: 645 rows)
# [1121.3s] Actual: 26.42, Predicted: 24.53
# No valid rows after processing global buffer
# Buffered row (total: 646 rows)
# [1122.9s] Actual: 26.42, Predicted: 24.53
# No valid rows after processing global buffer
# Buffered row (total: 647 rows)
# [1125.2s] Actual: 26.42, Predicted: 24.53
# No valid rows after processing global buffer
# Buffered row (total: 648 rows)
# [1127.9s] Actual: 37.76, Predicted: 41.01
# Current RMSE: 9.1338
# No valid rows after processing global buffer
# Buffered row (total: 649 rows)
# [1129.6s] Actual: 37.76, Predicted: 41.01
# No valid rows after processing global buffer
# Buffered row (total: 650 rows)
# [1131.2s] Actual: 37.76, Predicted: 41.01
# No valid rows after processing global buffer
# Buffered row (total: 651 rows)
# [1132.9s] Actual: 37.76, Predicted: 41.01
# No valid rows after processing global buffer
# Buffered row (total: 652 rows)
# [1134.5s] Actual: 37.50, Predicted: 44.20
# No valid rows after processing global buffer
# Buffered row (total: 653 rows)
# [1136.2s] Actual: 37.50, Predicted: 44.20
# No valid rows after processing global buffer
# Buffered row (total: 654 rows)
# [1137.8s] Actual: 37.50, Predicted: 44.20
# No valid rows after processing global buffer
# Buffered row (total: 655 rows)
# [1140.4s] Actual: 37.50, Predicted: 44.20
# No valid rows after processing global buffer
# Buffered row (total: 656 rows)
# [1142.8s] Actual: 37.01, Predicted: 48.57
# No valid rows after processing global buffer
# Buffered row (total: 657 rows)
# [1144.4s] Actual: 37.01, Predicted: 48.57
# No valid rows after processing global buffer
# Buffered row (total: 658 rows)
# [1146.0s] Actual: 29.91, Predicted: 32.41
# Current RMSE: 9.0996
# No valid rows after processing global buffer
# Buffered row (total: 659 rows)
# [1147.7s] Actual: 29.91, Predicted: 32.41
# No valid rows after processing global buffer
# Buffered row (total: 660 rows)
# [1149.3s] Actual: 29.91, Predicted: 32.41
# No valid rows after processing global buffer
# Buffered row (total: 661 rows)
# [1151.0s] Actual: 29.91, Predicted: 32.41
# No valid rows after processing global buffer
# Buffered row (total: 662 rows)
# [1152.7s] Actual: 33.53, Predicted: 29.17
# No valid rows after processing global buffer
# Buffered row (total: 663 rows)
# [1155.3s] Actual: 33.53, Predicted: 29.17
# No valid rows after processing global buffer
# Buffered row (total: 664 rows)
# [1157.5s] Actual: 33.53, Predicted: 29.17
# No valid rows after processing global buffer
# Buffered row (total: 665 rows)
# [1159.1s] Actual: 33.53, Predicted: 29.17
# No valid rows after processing global buffer
# Buffered row (total: 666 rows)
# [1160.8s] Actual: 33.34, Predicted: 22.24
# No valid rows after processing global buffer
# Buffered row (total: 667 rows)
# [1162.5s] Actual: 33.34, Predicted: 22.24
# No valid rows after processing global buffer
# Buffered row (total: 668 rows)
# [1164.2s] Actual: 33.34, Predicted: 22.24
# Current RMSE: 9.0645
# No valid rows after processing global buffer
# Buffered row (total: 669 rows)
# [1165.8s] Actual: 33.34, Predicted: 22.24
# No valid rows after processing global buffer
# Buffered row (total: 670 rows)
# [1168.0s] Actual: 36.21, Predicted: 35.66
# No valid rows after processing global buffer
# Buffered row (total: 671 rows)
# [1170.5s] Actual: 36.21, Predicted: 35.66
# No valid rows after processing global buffer
# Buffered row (total: 672 rows)
# [1172.5s] Actual: 37.06, Predicted: 47.54
# No valid rows after processing global buffer
# Buffered row (total: 673 rows)
# [1174.2s] Actual: 37.06, Predicted: 47.54
# No valid rows after processing global buffer
# Buffered row (total: 674 rows)
# [1175.8s] Actual: 37.06, Predicted: 47.54
# No valid rows after processing global buffer
# Buffered row (total: 675 rows)
# [1177.5s] Actual: 36.28, Predicted: 42.82
# No valid rows after processing global buffer
# Buffered row (total: 676 rows)
# [1179.1s] Actual: 36.28, Predicted: 42.82
# No valid rows after processing global buffer
# Buffered row (total: 677 rows)
# [1180.9s] Actual: 36.28, Predicted: 42.82
# No valid rows after processing global buffer
# Buffered row (total: 678 rows)
# [1183.1s] Actual: 29.33, Predicted: 25.43
# Current RMSE: 9.0431
# No valid rows after processing global buffer
# Buffered row (total: 679 rows)
# [1185.8s] Actual: 29.33, Predicted: 25.43
# No valid rows after processing global buffer
# Buffered row (total: 680 rows)
# [1187.4s] Actual: 29.33, Predicted: 25.43
# No valid rows after processing global buffer
# Buffered row (total: 681 rows)
# [1189.1s] Actual: 29.33, Predicted: 25.43
# No valid rows after processing global buffer
# Buffered row (total: 682 rows)
# [1191.0s] Actual: 29.33, Predicted: 25.43
# No valid rows after processing global buffer
# Buffered row (total: 683 rows)
# [1192.7s] Actual: 36.34, Predicted: 41.13
# No valid rows after processing global buffer
# Buffered row (total: 684 rows)
# [1194.4s] Actual: 36.34, Predicted: 41.13
# No valid rows after processing global buffer
# Buffered row (total: 685 rows)
# [1196.2s] Actual: 36.34, Predicted: 41.13
# No valid rows after processing global buffer
# Buffered row (total: 686 rows)
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/socket.py", line 718, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Shutting down...
# Unprocessed rows remaining: 686
# Final RMSE: 9.0013 from 587 predictions

# %% [markdown]
# As observed linear regression performs better compared to random forest and the RMSE also is far better for linear regression model

# %% [markdown]
# ##Train ARIMA model

# %% [markdown]
# ## Question 2: Consumer code for ARIMA model

# %%
from kafka import KafkaConsumer
import json
import pandas as pd
import joblib
from statsmodels.tsa.arima.model import ARIMAResults
from sklearn.preprocessing import StandardScaler
import numpy as np

# Load ARIMA model
model_fit = ARIMAResults.load("/content/drive/My Drive/DATS6450-Project4/arima_model.pkl")

# Load the scaler
scaler = joblib.load("/content/drive/My Drive/DATS6450-Project4/arima_scaler.pkl")

# Kafka setup
TOPIC_NAME = "streaming_11"
SASL_MECHANISM = 'SCRAM-SHA-256'
bootstrap_servers = f"kafka-28c8ad04-rachanak0611-3f37.j.aivencloud.com:19404"
kafka_password = "AVNS_BpO_fc9_Co4g5b3_ehW"

consumer = KafkaConsumer(
    TOPIC_NAME,
    auto_offset_reset="earliest",
    bootstrap_servers=bootstrap_servers,
    client_id="CONSUMER_CLIENT_ID",
    group_id="CONSUMER_GROUP_ID",
    sasl_mechanism=SASL_MECHANISM,
    sasl_plain_username="avnadmin",
    sasl_plain_password=kafka_password,
    security_protocol="SASL_SSL",
    ssl_cafile="/content/drive/My Drive/DATS6450-Project4/ca.pem"
)

lbmp_series = []

print("Listening to Kafka stream...")

for message in consumer:
    message_str = message.value.decode('utf-8')

    try:
        data = json.loads(message_str)
    except json.JSONDecodeError:
        print(f"Failed to decode message: {message_str}")
        continue

    try:
        lbmp_val = pd.to_numeric(data["LBMP"], errors='coerce')

        if pd.isna(lbmp_val):
            continue

        try:
            lbmp_scaled = scaler.transform([[lbmp_val]])[0][0]
        except ValueError:

            print("Scaler not fitted. Fitting with available data...")
            scaler.fit([[lbmp_val]])
            joblib.dump(scaler, "/content/drive/My Drive/DATS6450-Project4/arima_scaler.pkl")  # Save the fitted scaler
            lbmp_scaled = lbmp_val
            print("Scaler refitted and saved.")

        lbmp_series.append(lbmp_scaled)
        print(f"Scaled LBMP value: {lbmp_scaled}")

    except KeyError:
        print(f"Key 'LBMP' not found in the message: {data}")
        continue
    except Exception as e:
        print(f"Error processing LBMP value: {e}")
        continue

    # Process the LBMP series once enough data is collected
    if len(lbmp_series) >= 10:
        series = pd.Series(lbmp_series)

        # Make prediction
        pred = model_fit.predict(start=0, end=len(series) - 1)
        residual = series.iloc[-1] - pred.iloc[-1]

        # Calculate MAD (Median Absolute Deviation) for dynamic thresholding
        median_residual = np.median(series - pred)
        mad = np.median(np.abs((series - pred) - median_residual))

        # Set dynamic thresholds based on MAD
        anomaly_threshold_upper = median_residual + 3 * mad
        anomaly_threshold_lower = median_residual - 3 * mad

        # Determine if anomaly based on residual and dynamic thresholds
        is_anomaly = int((residual > anomaly_threshold_upper) or (residual < anomaly_threshold_lower))

        # Output the results
        print(f"Time: {data.get('timestamp', 'N/A')}, LBMP: {lbmp_val:.2f}, Scaled: {lbmp_scaled:.2f}, Residual: {residual:.2f}, Anomaly: {is_anomaly}")
    else:
        print(f"Waiting for more data... ({len(lbmp_series)} collected)")
# Out:
# Listening to Kafka stream...
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=3 host=34.95.23.216:19404 <connecting> [IPv4 ('34.95.23.216', 19404)]>: Connect attempt returned error 110. Disconnecting.
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=3 host=34.95.23.216:19404 <connecting> [IPv4 ('34.95.23.216', 19404)]>: Closing connection. KafkaConnectionError: 110 ETIMEDOUT
# WARNING:kafka.client:Node 3 connection failed -- refreshing metadata
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=2 host=35.203.26.124:19404 <connecting> [IPv4 ('35.203.26.124', 19404)]>: Connect attempt returned error 110. Disconnecting.
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=2 host=35.203.26.124:19404 <connecting> [IPv4 ('35.203.26.124', 19404)]>: Closing connection. KafkaConnectionError: 110 ETIMEDOUT
# WARNING:kafka.client:Node 2 connection failed -- refreshing metadata
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=1 host=34.118.173.179:19404 <connecting> [IPv4 ('34.118.173.179', 19404)]>: Connect attempt returned error 110. Disconnecting.
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=1 host=34.118.173.179:19404 <connecting> [IPv4 ('34.118.173.179', 19404)]>: Closing connection. KafkaConnectionError: 110 ETIMEDOUT
# WARNING:kafka.client:Node 1 connection failed -- refreshing metadata
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group CONSUMER_GROUP_ID because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat poll expired, leaving group
# ERROR:kafka.coordinator:Heartbeat thread for group CONSUMER_GROUP_ID failed due to unexpected error: cannot release un-acquired lock
# Scaled LBMP value: 11.100000000000001
# Waiting for more data... (1 collected)
# Scaled LBMP value: 10.66
# Waiting for more data... (2 collected)
# Scaled LBMP value: 9.3
# Waiting for more data... (3 collected)
# Scaled LBMP value: 7.420000000000002
# Waiting for more data... (4 collected)
# Scaled LBMP value: 11.120000000000001
# Waiting for more data... (5 collected)
# Scaled LBMP value: 11.830000000000002
# Waiting for more data... (6 collected)
# Scaled LBMP value: 8.95
# Waiting for more data... (7 collected)
# Scaled LBMP value: 11.379999999999999
# Waiting for more data... (8 collected)
# Scaled LBMP value: 12.600000000000001
# Waiting for more data... (9 collected)
# Scaled LBMP value: 11.61
# Time: 2001-06-02T20:32:32Z, LBMP: 24.47, Scaled: 11.61, Residual: 11.86, Anomaly: 0
# Scaled LBMP value: 11.129999999999999
# Time: 2001-06-02T20:32:32Z, LBMP: 23.99, Scaled: 11.13, Residual: 11.39, Anomaly: 0
# Scaled LBMP value: 9.010000000000002
# Time: 2001-06-02T20:32:32Z, LBMP: 21.87, Scaled: 9.01, Residual: 9.57, Anomaly: 0
# Scaled LBMP value: 14.39
# Time: 2001-06-02T20:34:32Z, LBMP: 27.25, Scaled: 14.39, Residual: 15.30, Anomaly: 1
# Scaled LBMP value: 17.47
# Time: 2001-06-02T20:34:32Z, LBMP: 30.33, Scaled: 17.47, Residual: 18.63, Anomaly: 1
# Scaled LBMP value: 16.27
# Time: 2001-06-02T20:34:32Z, LBMP: 29.13, Scaled: 16.27, Residual: 17.60, Anomaly: 1
# Scaled LBMP value: 13.150000000000002
# Time: 2001-06-02T20:34:32Z, LBMP: 26.01, Scaled: 13.15, Residual: 14.56, Anomaly: 0
# Scaled LBMP value: 17.37
# Time: 2001-06-02T20:39:32Z, LBMP: 30.23, Scaled: 17.37, Residual: 18.81, Anomaly: 1
# Scaled LBMP value: 18.310000000000002
# Time: 2001-06-02T20:39:32Z, LBMP: 31.17, Scaled: 18.31, Residual: 19.76, Anomaly: 1
# Scaled LBMP value: 17.740000000000002
# Time: 2001-06-02T20:39:32Z, LBMP: 30.60, Scaled: 17.74, Residual: 19.20, Anomaly: 1
# Scaled LBMP value: 13.54
# Time: 2001-06-02T20:41:02Z, LBMP: 26.40, Scaled: 13.54, Residual: 15.01, Anomaly: 0
# Scaled LBMP value: 11.760000000000002
# Time: 2001-06-02T20:41:02Z, LBMP: 24.62, Scaled: 11.76, Residual: 13.26, Anomaly: 0
# Scaled LBMP value: 11.170000000000002
# Time: 2001-06-02T20:41:02Z, LBMP: 24.03, Scaled: 11.17, Residual: 12.69, Anomaly: 0
# Scaled LBMP value: 13.86
# Time: 2001-06-02T20:41:02Z, LBMP: 26.72, Scaled: 13.86, Residual: 15.40, Anomaly: 0
# Scaled LBMP value: 13.940000000000001
# Time: 2001-06-02T20:41:02Z, LBMP: 26.80, Scaled: 13.94, Residual: 15.48, Anomaly: 0
# Scaled LBMP value: 13.25
# Time: 2001-06-02T20:43:32Z, LBMP: 26.11, Scaled: 13.25, Residual: 14.48, Anomaly: 0
# Scaled LBMP value: 12.64
# Time: 2001-06-02T20:43:32Z, LBMP: 25.50, Scaled: 12.64, Residual: 13.51, Anomaly: 0
# Scaled LBMP value: 15.55
# Time: 2001-06-02T20:43:32Z, LBMP: 28.41, Scaled: 15.55, Residual: 16.16, Anomaly: 0
# Scaled LBMP value: 13.8
# Time: 2001-06-02T20:43:32Z, LBMP: 26.66, Scaled: 13.80, Residual: 14.25, Anomaly: 0
# Scaled LBMP value: 11.48
# Time: 2001-06-02T20:43:32Z, LBMP: 24.34, Scaled: 11.48, Residual: 11.84, Anomaly: 0
# Scaled LBMP value: 15.36
# Time: 2001-06-02T20:48:32Z, LBMP: 28.22, Scaled: 15.36, Residual: 15.71, Anomaly: 0
# Scaled LBMP value: 18.34
# Time: 2001-06-02T20:48:32Z, LBMP: 31.20, Scaled: 18.34, Residual: 18.71, Anomaly: 0
# Scaled LBMP value: 17.76
# Time: 2001-06-02T20:48:32Z, LBMP: 30.62, Scaled: 17.76, Residual: 18.16, Anomaly: 0
# Scaled LBMP value: 16.55
# Time: 2001-06-02T20:48:32Z, LBMP: 29.41, Scaled: 16.55, Residual: 16.97, Anomaly: 0
# Scaled LBMP value: 17.39
# Time: 2001-06-02T20:50:02Z, LBMP: 30.25, Scaled: 17.39, Residual: 17.82, Anomaly: 0
# Scaled LBMP value: 18.25
# Time: 2001-06-02T20:50:02Z, LBMP: 31.11, Scaled: 18.25, Residual: 18.69, Anomaly: 0
# Scaled LBMP value: 14.66
# Time: 2001-06-02T20:50:02Z, LBMP: 27.52, Scaled: 14.66, Residual: 15.09, Anomaly: 0
# Scaled LBMP value: 17.67
# Time: 2001-06-02T20:50:02Z, LBMP: 30.53, Scaled: 17.67, Residual: 18.09, Anomaly: 0
# Scaled LBMP value: 17.76
# Time: 2001-06-02T20:50:02Z, LBMP: 30.62, Scaled: 17.76, Residual: 18.18, Anomaly: 0
# Scaled LBMP value: 13.280000000000001
# Time: 2001-06-02T20:50:02Z, LBMP: 26.14, Scaled: 13.28, Residual: 13.70, Anomaly: 0
# Scaled LBMP value: 12.32
# Time: 2001-06-02T20:55:02Z, LBMP: 25.18, Scaled: 12.32, Residual: 12.73, Anomaly: 0
# Scaled LBMP value: 13.080000000000002
# Time: 2001-06-02T20:55:02Z, LBMP: 25.94, Scaled: 13.08, Residual: 13.49, Anomaly: 0
# Scaled LBMP value: 8.920000000000002
# Time: 2001-06-02T20:55:02Z, LBMP: 21.78, Scaled: 8.92, Residual: 9.32, Anomaly: 0
# Scaled LBMP value: 10.969999999999999
# Time: 2001-06-02T20:56:32Z, LBMP: 23.83, Scaled: 10.97, Residual: 11.37, Anomaly: 0
# Scaled LBMP value: 12.010000000000002
# Time: 2001-06-02T20:56:32Z, LBMP: 24.87, Scaled: 12.01, Residual: 12.38, Anomaly: 0
# Scaled LBMP value: 11.690000000000001
# Time: 2001-06-02T21:00:00Z, LBMP: 24.55, Scaled: 11.69, Residual: 12.03, Anomaly: 0
# Scaled LBMP value: 11.940000000000001
# Time: 2001-06-02T21:00:00Z, LBMP: 24.80, Scaled: 11.94, Residual: 12.26, Anomaly: 0
# Scaled LBMP value: 10.969999999999999
# Time: 2001-06-02T21:00:00Z, LBMP: 23.83, Scaled: 10.97, Residual: 11.27, Anomaly: 0
# Scaled LBMP value: 12.010000000000002
# Time: 2001-06-02T21:00:00Z, LBMP: 24.87, Scaled: 12.01, Residual: 12.33, Anomaly: 0
# Scaled LBMP value: 10.5
# Time: 2001-06-02T21:00:00Z, LBMP: 23.36, Scaled: 10.50, Residual: 10.83, Anomaly: 0
# Scaled LBMP value: 8.36
# Time: 2001-06-02T21:00:00Z, LBMP: 21.22, Scaled: 8.36, Residual: 8.71, Anomaly: 0
# Scaled LBMP value: 8.79
# Time: 2001-06-02T21:01:32Z, LBMP: 21.65, Scaled: 8.79, Residual: 9.14, Anomaly: 0
# Scaled LBMP value: 11.150000000000002
# Time: 2001-06-02T21:01:32Z, LBMP: 24.01, Scaled: 11.15, Residual: 11.50, Anomaly: 0
# Scaled LBMP value: 11.219999999999999
# Time: 2001-06-02T21:01:32Z, LBMP: 24.08, Scaled: 11.22, Residual: 11.55, Anomaly: 0
# Scaled LBMP value: 9.760000000000002
# Time: 2001-06-02T21:01:32Z, LBMP: 22.62, Scaled: 9.76, Residual: 10.07, Anomaly: 0
# Scaled LBMP value: 13.21
# Time: 2001-06-02T21:04:32Z, LBMP: 26.07, Scaled: 13.21, Residual: 13.51, Anomaly: 0
# Scaled LBMP value: 13.879999999999999
# Time: 2001-06-02T21:04:32Z, LBMP: 26.74, Scaled: 13.88, Residual: 14.18, Anomaly: 0
# Scaled LBMP value: 10.850000000000001
# Time: 2001-06-02T21:04:32Z, LBMP: 23.71, Scaled: 10.85, Residual: 11.45, Anomaly: 0
# Scaled LBMP value: 13.469999999999999
# Time: 2001-06-02T21:04:32Z, LBMP: 26.33, Scaled: 13.47, Residual: 14.40, Anomaly: 0
# Scaled LBMP value: 17.95
# Time: 2001-06-02T21:06:32Z, LBMP: 30.81, Scaled: 17.95, Residual: 19.12, Anomaly: 0
# Scaled LBMP value: 15.780000000000001
# Time: 2001-06-02T21:06:32Z, LBMP: 28.64, Scaled: 15.78, Residual: 17.10, Anomaly: 0
# Scaled LBMP value: 18.69
# Time: 2001-06-02T21:06:32Z, LBMP: 31.55, Scaled: 18.69, Residual: 20.10, Anomaly: 1
# Scaled LBMP value: 15.18
# Time: 2001-06-02T21:06:32Z, LBMP: 28.04, Scaled: 15.18, Residual: 16.61, Anomaly: 0
# Scaled LBMP value: 18.13
# Time: 2001-06-02T21:06:32Z, LBMP: 30.99, Scaled: 18.13, Residual: 19.58, Anomaly: 0
# Scaled LBMP value: 18.2
# Time: 2001-06-02T21:06:32Z, LBMP: 31.06, Scaled: 18.20, Residual: 19.66, Anomaly: 0
# Scaled LBMP value: 16.39
# Time: 2001-06-02T21:06:32Z, LBMP: 29.25, Scaled: 16.39, Residual: 17.58, Anomaly: 0
# Scaled LBMP value: 17.810000000000002
# Time: 2001-06-02T21:08:02Z, LBMP: 30.67, Scaled: 17.81, Residual: 18.69, Anomaly: 0
# Scaled LBMP value: 14.3
# Time: 2001-06-02T21:08:02Z, LBMP: 27.16, Scaled: 14.30, Residual: 14.96, Anomaly: 0
# Scaled LBMP value: 16.12
# Time: 2001-06-02T21:08:02Z, LBMP: 28.98, Scaled: 16.12, Residual: 16.64, Anomaly: 0
# Scaled LBMP value: 15.52
# Time: 2001-06-02T21:08:02Z, LBMP: 28.38, Scaled: 15.52, Residual: 15.97, Anomaly: 0
# Scaled LBMP value: 12.54
# Time: 2001-06-02T21:13:02Z, LBMP: 25.40, Scaled: 12.54, Residual: 12.99, Anomaly: 0
# Scaled LBMP value: 10.73
# Time: 2001-06-02T21:13:02Z, LBMP: 23.59, Scaled: 10.73, Residual: 11.17, Anomaly: 0
# Scaled LBMP value: 10.18
# Time: 2001-06-02T21:13:02Z, LBMP: 23.04, Scaled: 10.18, Residual: 10.61, Anomaly: 0
# Scaled LBMP value: 12.780000000000001
# Time: 2001-06-02T21:13:02Z, LBMP: 25.64, Scaled: 12.78, Residual: 13.20, Anomaly: 0
# Scaled LBMP value: 11.740000000000002
# Time: 2001-06-02T21:17:32Z, LBMP: 24.60, Scaled: 11.74, Residual: 12.16, Anomaly: 0
# Scaled LBMP value: 11.91
# Time: 2001-06-02T21:17:32Z, LBMP: 24.77, Scaled: 11.91, Residual: 12.33, Anomaly: 0
# Scaled LBMP value: 11.969999999999999
# Time: 2001-06-02T21:17:32Z, LBMP: 24.83, Scaled: 11.97, Residual: 12.39, Anomaly: 0
# Scaled LBMP value: 10.469999999999999
# Time: 2001-06-02T21:17:32Z, LBMP: 23.33, Scaled: 10.47, Residual: 10.88, Anomaly: 0
# Scaled LBMP value: 8.34
# Time: 2001-06-02T21:17:32Z, LBMP: 21.20, Scaled: 8.34, Residual: 8.75, Anomaly: 0
# Scaled LBMP value: 12.25
# Time: 2001-06-02T21:19:32Z, LBMP: 25.11, Scaled: 12.25, Residual: 12.65, Anomaly: 0
# Scaled LBMP value: 12.870000000000001
# Time: 2001-06-02T21:19:32Z, LBMP: 25.73, Scaled: 12.87, Residual: 13.27, Anomaly: 0
# Scaled LBMP value: 12.400000000000002
# Time: 2001-06-02T21:19:32Z, LBMP: 25.26, Scaled: 12.40, Residual: 12.80, Anomaly: 0
# Scaled LBMP value: 11.45
# Time: 2001-06-02T21:19:32Z, LBMP: 24.31, Scaled: 11.45, Residual: 11.85, Anomaly: 0
# Scaled LBMP value: 12.469999999999999
# Time: 2001-06-02T21:19:32Z, LBMP: 25.33, Scaled: 12.47, Residual: 12.86, Anomaly: 0
# Scaled LBMP value: 10.940000000000001
# Time: 2001-06-02T21:19:32Z, LBMP: 23.80, Scaled: 10.94, Residual: 11.33, Anomaly: 0
# Scaled LBMP value: 8.71
# Time: 2001-06-02T21:19:32Z, LBMP: 21.57, Scaled: 8.71, Residual: 9.10, Anomaly: 0
# Scaled LBMP value: 8.5
# Time: 2001-06-02T21:21:02Z, LBMP: 21.36, Scaled: 8.50, Residual: 9.17, Anomaly: 0
# Scaled LBMP value: 10.830000000000002
# Time: 2001-06-02T21:21:02Z, LBMP: 23.69, Scaled: 10.83, Residual: 11.81, Anomaly: 0
# Scaled LBMP value: 10.89
# Time: 2001-06-02T21:21:02Z, LBMP: 23.75, Scaled: 10.89, Residual: 12.10, Anomaly: 0
# Scaled LBMP value: 10.11
# Time: 2001-06-02T21:25:32Z, LBMP: 22.97, Scaled: 10.11, Residual: 11.48, Anomaly: 0
# Scaled LBMP value: 6.800000000000001
# Time: 2001-06-02T21:25:32Z, LBMP: 19.66, Scaled: 6.80, Residual: 8.24, Anomaly: 0
# Scaled LBMP value: 10.219999999999999
# Time: 2001-06-02T21:30:32Z, LBMP: 23.08, Scaled: 10.22, Residual: 11.68, Anomaly: 0
# Scaled LBMP value: 8.120000000000001
# Time: 2001-06-02T21:30:32Z, LBMP: 20.98, Scaled: 8.12, Residual: 9.60, Anomaly: 0
# Scaled LBMP value: 10.45
# Time: 2001-06-02T21:30:32Z, LBMP: 23.31, Scaled: 10.45, Residual: 11.68, Anomaly: 0
# Scaled LBMP value: 9.04
# Time: 2001-06-02T21:30:32Z, LBMP: 21.90, Scaled: 9.04, Residual: 9.97, Anomaly: 0
# Scaled LBMP value: 7.140000000000001
# Time: 2001-06-02T21:30:32Z, LBMP: 20.00, Scaled: 7.14, Residual: 7.85, Anomaly: 0
# Scaled LBMP value: 7.879999999999999
# Time: 2001-06-02T21:35:32Z, LBMP: 20.74, Scaled: 7.88, Residual: 8.46, Anomaly: 0
# Scaled LBMP value: 10.09
# Time: 2001-06-02T21:35:32Z, LBMP: 22.95, Scaled: 10.09, Residual: 10.86, Anomaly: 0
# Scaled LBMP value: 10.14
# Time: 2001-06-02T21:35:32Z, LBMP: 23.00, Scaled: 10.14, Residual: 11.21, Anomaly: 0
# Scaled LBMP value: 6.949999999999999
# Time: 2001-06-02T21:35:32Z, LBMP: 19.81, Scaled: 6.95, Residual: 7.96, Anomaly: 0
# Scaled LBMP value: 7.02
# Time: 2001-06-02T21:37:02Z, LBMP: 19.88, Scaled: 7.02, Residual: 7.84, Anomaly: 0
# Scaled LBMP value: 8.129999999999999
# Time: 2001-06-02T21:42:02Z, LBMP: 20.99, Scaled: 8.13, Residual: 8.79, Anomaly: 0
# Scaled LBMP value: 8.670000000000002
# Time: 2001-06-02T21:42:02Z, LBMP: 21.53, Scaled: 8.67, Residual: 9.20, Anomaly: 0
# Scaled LBMP value: 6.260000000000002
# Time: 2001-06-02T21:42:02Z, LBMP: 19.12, Scaled: 6.26, Residual: 6.71, Anomaly: 0
# Scaled LBMP value: 8.29
# Time: 2001-06-02T21:42:02Z, LBMP: 21.15, Scaled: 8.29, Residual: 8.73, Anomaly: 0
# Scaled LBMP value: 7.52
# Time: 2001-06-02T21:42:02Z, LBMP: 20.38, Scaled: 7.52, Residual: 7.95, Anomaly: 0
# Scaled LBMP value: 8.34
# Time: 2001-06-02T21:42:02Z, LBMP: 21.20, Scaled: 8.34, Residual: 8.76, Anomaly: 0
# Scaled LBMP value: 7.100000000000001
# Time: 2001-06-02T21:42:02Z, LBMP: 19.96, Scaled: 7.10, Residual: 7.51, Anomaly: 0
# Scaled LBMP value: 7.34
# Time: 2001-06-02T21:47:02Z, LBMP: 20.20, Scaled: 7.34, Residual: 7.74, Anomaly: 0
# Scaled LBMP value: 5.960000000000001
# Time: 2001-06-02T21:47:02Z, LBMP: 18.82, Scaled: 5.96, Residual: 6.36, Anomaly: 0
# Scaled LBMP value: 7.859999999999999
# Time: 2001-06-02T21:47:02Z, LBMP: 20.72, Scaled: 7.86, Residual: 8.25, Anomaly: 0
# Scaled LBMP value: 5.510000000000002
# Time: 2001-06-02T21:47:02Z, LBMP: 18.37, Scaled: 5.51, Residual: 6.18, Anomaly: 0
# Scaled LBMP value: 6.740000000000002
# Time: 2001-06-02T21:47:02Z, LBMP: 19.60, Scaled: 6.74, Residual: 7.74, Anomaly: 0
# Scaled LBMP value: 4.710000000000001
# Time: 2001-06-02T21:47:02Z, LBMP: 17.57, Scaled: 4.71, Residual: 5.95, Anomaly: 0
# Scaled LBMP value: 7.27
# Time: 2001-06-02T21:52:02Z, LBMP: 20.13, Scaled: 7.27, Residual: 8.38, Anomaly: 0
# Scaled LBMP value: 5.940000000000001
# Time: 2001-06-02T21:52:02Z, LBMP: 18.80, Scaled: 5.94, Residual: 6.81, Anomaly: 0
# Scaled LBMP value: 6.699999999999999
# Time: 2001-06-02T21:52:02Z, LBMP: 19.56, Scaled: 6.70, Residual: 7.35, Anomaly: 0
# Scaled LBMP value: 4.990000000000002
# Time: 2001-06-02T21:55:32Z, LBMP: 17.85, Scaled: 4.99, Residual: 5.51, Anomaly: 0
# Scaled LBMP value: 6.760000000000002
# Time: 2001-06-02T21:55:32Z, LBMP: 19.62, Scaled: 6.76, Residual: 7.21, Anomaly: 0
# Scaled LBMP value: 4.539999999999999
# Time: 2001-06-02T21:55:32Z, LBMP: 17.40, Scaled: 4.54, Residual: 4.98, Anomaly: 0
# Scaled LBMP value: 6.469999999999999
# Time: 2001-06-02T21:55:32Z, LBMP: 19.33, Scaled: 6.47, Residual: 6.91, Anomaly: 0
# Scaled LBMP value: 3.870000000000001
# Time: 2001-06-02T21:55:32Z, LBMP: 16.73, Scaled: 3.87, Residual: 4.30, Anomaly: 0
# Scaled LBMP value: 4.990000000000002
# Time: 2001-06-02T22:00:00Z, LBMP: 17.85, Scaled: 4.99, Residual: 5.41, Anomaly: 0
# Scaled LBMP value: 4.539999999999999
# Time: 2001-06-02T22:00:00Z, LBMP: 17.40, Scaled: 4.54, Residual: 4.96, Anomaly: 0
# Scaled LBMP value: 6.43
# Time: 2001-06-02T22:00:00Z, LBMP: 19.29, Scaled: 6.43, Residual: 6.84, Anomaly: 0
# Scaled LBMP value: 6.469999999999999
# Time: 2001-06-02T22:00:00Z, LBMP: 19.33, Scaled: 6.47, Residual: 6.88, Anomaly: 0
# Scaled LBMP value: 5.34
# Time: 2001-06-02T22:00:00Z, LBMP: 18.20, Scaled: 5.34, Residual: 5.74, Anomaly: 0
# Scaled LBMP value: 11.100000000000001
# Time: 2001-06-02T22:00:32Z, LBMP: 23.96, Scaled: 11.10, Residual: 11.50, Anomaly: 0
# Scaled LBMP value: 9.52
# Time: 2001-06-02T22:00:32Z, LBMP: 22.38, Scaled: 9.52, Residual: 9.92, Anomaly: 0
# Scaled LBMP value: 11.3
# Time: 2001-06-02T22:00:32Z, LBMP: 24.16, Scaled: 11.30, Residual: 11.76, Anomaly: 0
# Scaled LBMP value: 11.34
# Time: 2001-06-02T22:00:32Z, LBMP: 24.20, Scaled: 11.34, Residual: 11.87, Anomaly: 0
# Scaled LBMP value: 20.43
# Time: 2001-06-02T22:03:32Z, LBMP: 33.29, Scaled: 20.43, Residual: 21.01, Anomaly: 1
# Scaled LBMP value: 18.22
# Time: 2001-06-02T22:03:32Z, LBMP: 31.08, Scaled: 18.22, Residual: 18.84, Anomaly: 0
# Scaled LBMP value: 17.45
# Time: 2001-06-02T22:03:32Z, LBMP: 30.31, Scaled: 17.45, Residual: 18.08, Anomaly: 0
# Scaled LBMP value: 18.830000000000002
# Time: 2001-06-02T22:03:32Z, LBMP: 31.69, Scaled: 18.83, Residual: 19.40, Anomaly: 0
# Scaled LBMP value: 12.3
# Time: 2001-06-02T22:06:32Z, LBMP: 25.16, Scaled: 12.30, Residual: 12.80, Anomaly: 0
# Scaled LBMP value: 14.75
# Time: 2001-06-02T22:06:32Z, LBMP: 27.61, Scaled: 14.75, Residual: 15.20, Anomaly: 0
# Scaled LBMP value: 14.29
# Time: 2001-06-02T22:06:32Z, LBMP: 27.15, Scaled: 14.29, Residual: 14.71, Anomaly: 0
# Scaled LBMP value: 13.34
# Time: 2001-06-02T22:06:32Z, LBMP: 26.20, Scaled: 13.34, Residual: 13.74, Anomaly: 0
# Scaled LBMP value: 14.34
# Time: 2001-06-02T22:06:32Z, LBMP: 27.20, Scaled: 14.34, Residual: 14.74, Anomaly: 0
# Scaled LBMP value: 12.79
# Time: 2001-06-02T22:06:32Z, LBMP: 25.65, Scaled: 12.79, Residual: 13.19, Anomaly: 0
# Scaled LBMP value: 10.77
# Time: 2001-06-02T22:06:32Z, LBMP: 23.63, Scaled: 10.77, Residual: 11.17, Anomaly: 0
# Scaled LBMP value: 10.45
# Time: 2001-06-02T22:08:32Z, LBMP: 23.31, Scaled: 10.45, Residual: 10.84, Anomaly: 0
# Scaled LBMP value: 9.969999999999999
# Time: 2001-06-02T22:08:32Z, LBMP: 22.83, Scaled: 9.97, Residual: 10.36, Anomaly: 0
# Scaled LBMP value: 9.420000000000002
# Time: 2001-06-02T22:13:32Z, LBMP: 22.28, Scaled: 9.42, Residual: 10.09, Anomaly: 0
# Scaled LBMP value: 10.0
# Time: 2001-06-02T22:13:32Z, LBMP: 22.86, Scaled: 10.00, Residual: 10.98, Anomaly: 0
# Scaled LBMP value: 8.830000000000002
# Time: 2001-06-02T22:13:32Z, LBMP: 21.69, Scaled: 8.83, Residual: 10.03, Anomaly: 0
# Scaled LBMP value: 9.66
# Time: 2001-06-02T22:13:32Z, LBMP: 22.52, Scaled: 9.66, Residual: 11.01, Anomaly: 0
# Scaled LBMP value: 8.379999999999999
# Time: 2001-06-02T22:13:32Z, LBMP: 21.24, Scaled: 8.38, Residual: 9.82, Anomaly: 0
# Scaled LBMP value: 6.670000000000002
# Time: 2001-06-02T22:13:32Z, LBMP: 19.53, Scaled: 6.67, Residual: 8.13, Anomaly: 0
# Scaled LBMP value: 9.3
# Time: 2001-06-02T22:16:32Z, LBMP: 22.16, Scaled: 9.30, Residual: 10.77, Anomaly: 0
# Scaled LBMP value: 7.330000000000002
# Time: 2001-06-02T22:16:32Z, LBMP: 20.19, Scaled: 7.33, Residual: 8.82, Anomaly: 0
# Scaled LBMP value: 8.71
# Time: 2001-06-02T22:16:32Z, LBMP: 21.57, Scaled: 8.71, Residual: 10.22, Anomaly: 0
# Scaled LBMP value: 8.280000000000001
# Time: 2001-06-02T22:16:32Z, LBMP: 21.14, Scaled: 8.28, Residual: 9.81, Anomaly: 0
# Scaled LBMP value: 6.859999999999999
# Time: 2001-06-02T22:18:32Z, LBMP: 19.72, Scaled: 6.86, Residual: 8.40, Anomaly: 0
# Scaled LBMP value: 4.66
# Time: 2001-06-02T22:18:32Z, LBMP: 17.52, Scaled: 4.66, Residual: 6.21, Anomaly: 0
# Scaled LBMP value: 5.850000000000001
# Time: 2001-06-02T22:18:32Z, LBMP: 18.71, Scaled: 5.85, Residual: 7.41, Anomaly: 0
# Scaled LBMP value: 5.48
# Time: 2001-06-02T22:18:32Z, LBMP: 18.34, Scaled: 5.48, Residual: 7.04, Anomaly: 0
# Scaled LBMP value: 4.300000000000001
# Time: 2001-06-02T22:23:32Z, LBMP: 17.16, Scaled: 4.30, Residual: 5.87, Anomaly: 0
# Scaled LBMP value: 3.240000000000002
# Time: 2001-06-02T22:23:32Z, LBMP: 16.10, Scaled: 3.24, Residual: 4.82, Anomaly: 0
# Scaled LBMP value: 2.8500000000000014
# Time: 2001-06-02T22:23:32Z, LBMP: 15.71, Scaled: 2.85, Residual: 4.44, Anomaly: 0
# Scaled LBMP value: 3.900000000000002
# Time: 2001-06-02T22:23:32Z, LBMP: 16.76, Scaled: 3.90, Residual: 5.50, Anomaly: 0
# Scaled LBMP value: 2.3500000000000014
# Time: 2001-06-02T22:23:32Z, LBMP: 15.21, Scaled: 2.35, Residual: 3.96, Anomaly: 0
# Scaled LBMP value: 3.6099999999999994
# Time: 2001-06-02T22:28:32Z, LBMP: 16.47, Scaled: 3.61, Residual: 5.22, Anomaly: 0
# Scaled LBMP value: 2.630000000000001
# Time: 2001-06-02T22:28:32Z, LBMP: 15.49, Scaled: 2.63, Residual: 3.97, Anomaly: 0
# Scaled LBMP value: 4.129999999999999
# Time: 2001-06-02T22:28:32Z, LBMP: 16.99, Scaled: 4.13, Residual: 5.16, Anomaly: 0
# Scaled LBMP value: 3.240000000000002
# Time: 2001-06-02T22:28:32Z, LBMP: 16.10, Scaled: 3.24, Residual: 4.04, Anomaly: 0
# Scaled LBMP value: 2.92
# Time: 2001-06-02T22:28:32Z, LBMP: 15.78, Scaled: 2.92, Residual: 3.57, Anomaly: 0
# Scaled LBMP value: 3.0500000000000007
# Time: 2001-06-02T22:33:02Z, LBMP: 15.91, Scaled: 3.05, Residual: 3.62, Anomaly: 0
# Scaled LBMP value: 1.0099999999999998
# Time: 2001-06-02T22:34:32Z, LBMP: 13.87, Scaled: 1.01, Residual: 1.56, Anomaly: 1
# Scaled LBMP value: 1.4000000000000004
# Time: 2001-06-02T22:34:32Z, LBMP: 14.26, Scaled: 1.40, Residual: 1.94, Anomaly: 1
# Scaled LBMP value: -0.17999999999999972
# Time: 2001-06-02T22:34:32Z, LBMP: 12.68, Scaled: -0.18, Residual: 0.61, Anomaly: 1
# Scaled LBMP value: 0.6799999999999997
# Time: 2001-06-02T22:34:32Z, LBMP: 13.54, Scaled: 0.68, Residual: 1.77, Anomaly: 1
# Scaled LBMP value: 1.1900000000000013
# Time: 2001-06-02T22:34:32Z, LBMP: 14.05, Scaled: 1.19, Residual: 2.50, Anomaly: 0
# Scaled LBMP value: 0.33999999999999986
# Time: 2001-06-02T22:39:32Z, LBMP: 13.20, Scaled: 0.34, Residual: 1.79, Anomaly: 1
# Scaled LBMP value: -1.1099999999999994
# Time: 2001-06-02T22:39:32Z, LBMP: 11.75, Scaled: -1.11, Residual: 0.41, Anomaly: 1
# Scaled LBMP value: 0.13000000000000078
# Time: 2001-06-02T22:39:32Z, LBMP: 12.99, Scaled: 0.13, Residual: 1.65, Anomaly: 1
# Scaled LBMP value: -0.33000000000000007
# Time: 2001-06-02T22:39:32Z, LBMP: 12.53, Scaled: -0.33, Residual: 1.00, Anomaly: 1
# Scaled LBMP value: -0.5800000000000001
# Time: 2001-06-02T22:39:32Z, LBMP: 12.28, Scaled: -0.58, Residual: 0.52, Anomaly: 1
# Scaled LBMP value: 0.27000000000000135
# Time: 2001-06-02T22:44:32Z, LBMP: 13.13, Scaled: 0.27, Residual: 1.21, Anomaly: 1
# Scaled LBMP value: -0.4599999999999991
# Time: 2001-06-02T22:44:32Z, LBMP: 12.40, Scaled: -0.46, Residual: 0.37, Anomaly: 1
# Scaled LBMP value: -0.019999999999999574
# Time: 2001-06-02T22:44:32Z, LBMP: 12.84, Scaled: -0.02, Residual: 0.96, Anomaly: 1
# Scaled LBMP value: 0.47000000000000064
# Time: 2001-06-02T22:44:32Z, LBMP: 13.33, Scaled: 0.47, Residual: 1.67, Anomaly: 0
# Scaled LBMP value: -0.2699999999999996
# Time: 2001-06-02T22:44:32Z, LBMP: 12.59, Scaled: -0.27, Residual: 1.10, Anomaly: 1
# Scaled LBMP value: -1.0899999999999999
# Time: 2001-06-02T22:44:32Z, LBMP: 11.77, Scaled: -1.09, Residual: 0.40, Anomaly: 1
# Scaled LBMP value: -0.9100000000000001
# Time: 2001-06-02T22:49:32Z, LBMP: 11.95, Scaled: -0.91, Residual: 0.63, Anomaly: 1
# Scaled LBMP value: -0.1899999999999995
# Time: 2001-06-02T22:54:32Z, LBMP: 12.67, Scaled: -0.19, Residual: 1.37, Anomaly: 0
# Scaled LBMP value: -0.8499999999999996
# Time: 2001-06-02T22:54:32Z, LBMP: 12.01, Scaled: -0.85, Residual: 0.72, Anomaly: 1
# Scaled LBMP value: 0.20000000000000107
# Time: 2001-06-02T22:54:32Z, LBMP: 13.06, Scaled: 0.20, Residual: 1.77, Anomaly: 0
# Scaled LBMP value: -1.1799999999999997
# Time: 2001-06-02T22:54:32Z, LBMP: 11.68, Scaled: -1.18, Residual: 0.39, Anomaly: 1
# Scaled LBMP value: -0.4399999999999995
# Time: 2001-06-02T22:54:32Z, LBMP: 12.42, Scaled: -0.44, Residual: 1.13, Anomaly: 1
# Scaled LBMP value: -1.42
# Time: 2001-06-02T22:54:32Z, LBMP: 11.44, Scaled: -1.42, Residual: -0.05, Anomaly: 1
# Scaled LBMP value: 3.0600000000000005
# Time: 2001-06-02T22:56:02Z, LBMP: 15.92, Scaled: 3.06, Residual: 4.19, Anomaly: 0
# Scaled LBMP value: 1.8200000000000003
# Time: 2001-06-02T22:56:02Z, LBMP: 14.68, Scaled: 1.82, Residual: 2.78, Anomaly: 0
# Scaled LBMP value: 2.74
# Time: 2001-06-02T22:56:02Z, LBMP: 15.60, Scaled: 2.74, Residual: 3.59, Anomaly: 0
# Scaled LBMP value: 2.460000000000001
# Time: 2001-06-02T22:56:02Z, LBMP: 15.32, Scaled: 2.46, Residual: 3.20, Anomaly: 0
# Scaled LBMP value: 3.0600000000000005
# Time: 2001-06-02T23:00:00Z, LBMP: 15.92, Scaled: 3.06, Residual: 3.72, Anomaly: 0
# Scaled LBMP value: 2.210000000000001
# Time: 2001-06-02T23:00:00Z, LBMP: 15.07, Scaled: 2.21, Residual: 2.80, Anomaly: 0
# Scaled LBMP value: 3.530000000000001
# Time: 2001-06-02T23:00:00Z, LBMP: 16.39, Scaled: 3.53, Residual: 4.08, Anomaly: 0
# Scaled LBMP value: 3.289999999999999
# Time: 2001-06-02T23:00:00Z, LBMP: 16.15, Scaled: 3.29, Residual: 3.81, Anomaly: 0
# Scaled LBMP value: 3.3000000000000007
# Time: 2001-06-02T23:00:00Z, LBMP: 16.16, Scaled: 3.30, Residual: 3.81, Anomaly: 0
# Scaled LBMP value: 2.460000000000001
# Time: 2001-06-02T23:00:00Z, LBMP: 15.32, Scaled: 2.46, Residual: 2.95, Anomaly: 0
# Scaled LBMP value: 1.5099999999999998
# Time: 2001-06-02T23:00:00Z, LBMP: 14.37, Scaled: 1.51, Residual: 1.99, Anomaly: 0
# Scaled LBMP value: 27.03
# Time: 2001-06-02T23:01:02Z, LBMP: 39.89, Scaled: 27.03, Residual: 27.50, Anomaly: 1
# Scaled LBMP value: 27.730000000000004
# Time: 2001-06-02T23:01:02Z, LBMP: 40.59, Scaled: 27.73, Residual: 28.19, Anomaly: 1
# Scaled LBMP value: 27.14
# Time: 2001-06-02T23:01:02Z, LBMP: 40.00, Scaled: 27.14, Residual: 27.60, Anomaly: 1
# Scaled LBMP value: 25.380000000000003
# Time: 2001-06-02T23:01:02Z, LBMP: 38.24, Scaled: 25.38, Residual: 26.11, Anomaly: 1
# Scaled LBMP value: 10.650000000000002
# Time: 2001-06-02T23:06:02Z, LBMP: 23.51, Scaled: 10.65, Residual: 11.69, Anomaly: 0
# Scaled LBMP value: 7.390000000000001
# Time: 2001-06-02T23:07:32Z, LBMP: 20.25, Scaled: 7.39, Residual: 8.65, Anomaly: 0
# Scaled LBMP value: -13.79
# Time: 2001-06-02T23:12:02Z, LBMP: -0.93, Scaled: -13.79, Residual: -12.39, Anomaly: 1
# Scaled LBMP value: -13.84
# Time: 2001-06-02T23:12:02Z, LBMP: -0.98, Scaled: -13.84, Residual: -12.37, Anomaly: 1
# Scaled LBMP value: -13.82
# Time: 2001-06-02T23:12:02Z, LBMP: -0.96, Scaled: -13.82, Residual: -12.55, Anomaly: 1
# Scaled LBMP value: -13.84
# Time: 2001-06-02T23:12:02Z, LBMP: -0.98, Scaled: -13.84, Residual: -12.79, Anomaly: 1
# Scaled LBMP value: -13.74
# Time: 2001-06-02T23:12:02Z, LBMP: -0.88, Scaled: -13.74, Residual: -12.86, Anomaly: 1
# Scaled LBMP value: 1.7200000000000006
# Time: 2001-06-02T23:17:02Z, LBMP: 14.58, Scaled: 1.72, Residual: 2.72, Anomaly: 0
# Scaled LBMP value: 2.7700000000000014
# Time: 2001-06-02T23:17:02Z, LBMP: 15.63, Scaled: 2.77, Residual: 3.96, Anomaly: 0
# Scaled LBMP value: 2.290000000000001
# Time: 2001-06-02T23:17:02Z, LBMP: 15.15, Scaled: 2.29, Residual: 3.66, Anomaly: 0
# Scaled LBMP value: 1.1900000000000013
# Time: 2001-06-02T23:17:02Z, LBMP: 14.05, Scaled: 1.19, Residual: 2.66, Anomaly: 0
# Scaled LBMP value: 2.16
# Time: 2001-06-02T23:18:32Z, LBMP: 15.02, Scaled: 2.16, Residual: 3.69, Anomaly: 0
# Scaled LBMP value: 1.9700000000000006
# Time: 2001-06-02T23:18:32Z, LBMP: 14.83, Scaled: 1.97, Residual: 3.51, Anomaly: 0
# Scaled LBMP value: 2.7200000000000006
# Time: 2001-06-02T23:18:32Z, LBMP: 15.58, Scaled: 2.72, Residual: 4.26, Anomaly: 0
# Scaled LBMP value: 3.0
# Time: 2001-06-02T23:18:32Z, LBMP: 15.86, Scaled: 3.00, Residual: 4.56, Anomaly: 0
# Scaled LBMP value: 2.5
# Time: 2001-06-02T23:18:32Z, LBMP: 15.36, Scaled: 2.50, Residual: 4.06, Anomaly: 0
# Scaled LBMP value: 2.9800000000000004
# Time: 2001-06-02T23:23:32Z, LBMP: 15.84, Scaled: 2.98, Residual: 4.56, Anomaly: 0
# Scaled LBMP value: 1.6600000000000001
# Time: 2001-06-02T23:23:32Z, LBMP: 14.52, Scaled: 1.66, Residual: 3.24, Anomaly: 0
# Scaled LBMP value: 2.2300000000000004
# Time: 2001-06-02T23:23:32Z, LBMP: 15.09, Scaled: 2.23, Residual: 3.82, Anomaly: 0
# Scaled LBMP value: 1.7300000000000004
# Time: 2001-06-02T23:28:32Z, LBMP: 14.59, Scaled: 1.73, Residual: 3.31, Anomaly: 0
# Scaled LBMP value: 2.790000000000001
# Time: 2001-06-02T23:28:32Z, LBMP: 15.65, Scaled: 2.79, Residual: 4.37, Anomaly: 0
# Scaled LBMP value: 2.280000000000001
# Time: 2001-06-02T23:28:32Z, LBMP: 15.14, Scaled: 2.28, Residual: 3.88, Anomaly: 0
# Scaled LBMP value: 34.22
# Time: 2001-06-02T23:31:32Z, LBMP: 47.08, Scaled: 34.22, Residual: 35.83, Anomaly: 1
# Scaled LBMP value: 34.36
# Time: 2001-06-02T23:31:32Z, LBMP: 47.22, Scaled: 34.36, Residual: 35.98, Anomaly: 1
# Scaled LBMP value: 30.53
# Time: 2001-06-02T23:31:32Z, LBMP: 43.39, Scaled: 30.53, Residual: 32.15, Anomaly: 1
# Scaled LBMP value: 28.89
# Time: 2001-06-02T23:31:32Z, LBMP: 41.75, Scaled: 28.89, Residual: 30.50, Anomaly: 1
# Scaled LBMP value: 14.580000000000002
# Time: 2001-06-02T23:35:32Z, LBMP: 27.44, Scaled: 14.58, Residual: 16.19, Anomaly: 0
# Scaled LBMP value: 12.850000000000001
# Time: 2001-06-02T23:35:32Z, LBMP: 25.71, Scaled: 12.85, Residual: 14.45, Anomaly: 0
# Scaled LBMP value: 14.7
# Time: 2001-06-02T23:35:32Z, LBMP: 27.56, Scaled: 14.70, Residual: 16.04, Anomaly: 0
# Scaled LBMP value: 14.34
# Time: 2001-06-02T23:35:32Z, LBMP: 27.20, Scaled: 14.34, Residual: 15.37, Anomaly: 0
# Scaled LBMP value: 13.850000000000001
# Time: 2001-06-02T23:35:32Z, LBMP: 26.71, Scaled: 13.85, Residual: 14.67, Anomaly: 0
# Scaled LBMP value: 14.310000000000002
# Time: 2001-06-02T23:35:32Z, LBMP: 27.17, Scaled: 14.31, Residual: 14.98, Anomaly: 0
# Scaled LBMP value: 13.420000000000002
# Time: 2001-06-02T23:35:32Z, LBMP: 26.28, Scaled: 13.42, Residual: 14.02, Anomaly: 0
# Scaled LBMP value: 2.3000000000000007
# Time: 2001-06-02T23:39:32Z, LBMP: 15.16, Scaled: 2.30, Residual: 2.88, Anomaly: 0
# Scaled LBMP value: 2.0500000000000007
# Time: 2001-06-02T23:39:32Z, LBMP: 14.91, Scaled: 2.05, Residual: 2.61, Anomaly: 0
# Scaled LBMP value: 2.6500000000000004
# Time: 2001-06-02T23:39:32Z, LBMP: 15.51, Scaled: 2.65, Residual: 3.19, Anomaly: 0
# Scaled LBMP value: 1.5099999999999998
# Time: 2001-06-02T23:39:32Z, LBMP: 14.37, Scaled: 1.51, Residual: 2.04, Anomaly: 0
# Scaled LBMP value: 3.08
# Time: 2001-06-02T23:44:32Z, LBMP: 15.94, Scaled: 3.08, Residual: 3.59, Anomaly: 0
# Scaled LBMP value: 1.7300000000000004
# Time: 2001-06-02T23:44:32Z, LBMP: 14.59, Scaled: 1.73, Residual: 2.24, Anomaly: 0
# Scaled LBMP value: 2.3200000000000003
# Time: 2001-06-02T23:44:32Z, LBMP: 15.18, Scaled: 2.32, Residual: 2.81, Anomaly: 0
# Scaled LBMP value: 1.2100000000000009
# Time: 2001-06-02T23:44:32Z, LBMP: 14.07, Scaled: 1.21, Residual: 1.69, Anomaly: 0
# Scaled LBMP value: 33.75
# Time: 2001-06-02T23:46:32Z, LBMP: 46.61, Scaled: 33.75, Residual: 34.22, Anomaly: 1
# Scaled LBMP value: 28.78
# Time: 2001-06-02T23:46:32Z, LBMP: 41.64, Scaled: 28.78, Residual: 29.25, Anomaly: 1
# Scaled LBMP value: 14.600000000000001
# Time: 2001-06-02T23:51:32Z, LBMP: 27.46, Scaled: 14.60, Residual: 15.06, Anomaly: 0
# Scaled LBMP value: 12.780000000000001
# Time: 2001-06-02T23:51:32Z, LBMP: 25.64, Scaled: 12.78, Residual: 13.23, Anomaly: 0
# Scaled LBMP value: 14.670000000000002
# Time: 2001-06-02T23:51:32Z, LBMP: 27.53, Scaled: 14.67, Residual: 15.12, Anomaly: 0
# Scaled LBMP value: 14.32
# Time: 2001-06-02T23:51:32Z, LBMP: 27.18, Scaled: 14.32, Residual: 14.77, Anomaly: 0
# Scaled LBMP value: 13.830000000000002
# Time: 2001-06-02T23:51:32Z, LBMP: 26.69, Scaled: 13.83, Residual: 14.27, Anomaly: 0
# Scaled LBMP value: 14.280000000000001
# Time: 2001-06-02T23:51:32Z, LBMP: 27.14, Scaled: 14.28, Residual: 14.72, Anomaly: 0
# Scaled LBMP value: 36.38
# Time: 2001-06-02T23:55:32Z, LBMP: 49.24, Scaled: 36.38, Residual: 36.82, Anomaly: 1
# Scaled LBMP value: 33.15
# Time: 2001-06-02T23:55:32Z, LBMP: 46.01, Scaled: 33.15, Residual: 33.64, Anomaly: 1
# Scaled LBMP value: 36.57
# Time: 2001-06-02T23:55:32Z, LBMP: 49.43, Scaled: 36.57, Residual: 37.12, Anomaly: 1
# Scaled LBMP value: 35.94
# Time: 2001-06-02T23:55:32Z, LBMP: 48.80, Scaled: 35.94, Residual: 36.54, Anomaly: 1
# Scaled LBMP value: 35.05
# Time: 2001-06-02T23:55:32Z, LBMP: 47.91, Scaled: 35.05, Residual: 35.68, Anomaly: 1
# Scaled LBMP value: 30.78
# Time: 2001-06-02T23:55:32Z, LBMP: 43.64, Scaled: 30.78, Residual: 31.42, Anomaly: 1
# Scaled LBMP value: 32.34
# Time: 2001-06-03T00:00:00Z, LBMP: 45.20, Scaled: 32.34, Residual: 32.98, Anomaly: 1
# Scaled LBMP value: 34.230000000000004
# Time: 2001-06-03T00:00:00Z, LBMP: 47.09, Scaled: 34.23, Residual: 34.88, Anomaly: 1
# Scaled LBMP value: 41.28
# Time: 2001-06-03T00:00:32Z, LBMP: 54.14, Scaled: 41.28, Residual: 41.93, Anomaly: 1
# Scaled LBMP value: 36.57
# Time: 2001-06-03T00:00:32Z, LBMP: 49.43, Scaled: 36.57, Residual: 37.22, Anomaly: 1
# Scaled LBMP value: 40.6
# Time: 2001-06-03T00:00:32Z, LBMP: 53.46, Scaled: 40.60, Residual: 41.20, Anomaly: 1
# Scaled LBMP value: 40.52
# Time: 2001-06-03T00:00:32Z, LBMP: 53.38, Scaled: 40.52, Residual: 41.06, Anomaly: 1
# Scaled LBMP value: 40.76
# Time: 2001-06-03T00:02:02Z, LBMP: 53.62, Scaled: 40.76, Residual: 41.25, Anomaly: 1
# Scaled LBMP value: 40.94
# Time: 2001-06-03T00:02:02Z, LBMP: 53.80, Scaled: 40.94, Residual: 41.41, Anomaly: 1
# Scaled LBMP value: 36.22
# Time: 2001-06-03T00:02:02Z, LBMP: 49.08, Scaled: 36.22, Residual: 36.67, Anomaly: 1
# Scaled LBMP value: 40.26
# Time: 2001-06-03T00:02:02Z, LBMP: 53.12, Scaled: 40.26, Residual: 40.70, Anomaly: 1
# Scaled LBMP value: 39.28
# Time: 2001-06-03T00:02:02Z, LBMP: 52.14, Scaled: 39.28, Residual: 39.72, Anomaly: 1
# Scaled LBMP value: 21.590000000000003
# Time: 2001-06-03T00:05:32Z, LBMP: 34.45, Scaled: 21.59, Residual: 22.03, Anomaly: 0
# Scaled LBMP value: 24.270000000000003
# Time: 2001-06-03T00:05:32Z, LBMP: 37.13, Scaled: 24.27, Residual: 24.71, Anomaly: 0
# Scaled LBMP value: 20.92
# Time: 2001-06-03T00:05:32Z, LBMP: 33.78, Scaled: 20.92, Residual: 21.36, Anomaly: 0
# Scaled LBMP value: 23.79
# Time: 2001-06-03T00:05:32Z, LBMP: 36.65, Scaled: 23.79, Residual: 24.23, Anomaly: 0
# Scaled LBMP value: 23.75
# Time: 2001-06-03T00:05:32Z, LBMP: 36.61, Scaled: 23.75, Residual: 24.19, Anomaly: 0
# Scaled LBMP value: 22.53
# Time: 2001-06-03T00:05:32Z, LBMP: 35.39, Scaled: 22.53, Residual: 23.02, Anomaly: 0
# Scaled LBMP value: 22.79
# Time: 2001-06-03T00:07:02Z, LBMP: 35.65, Scaled: 22.79, Residual: 23.34, Anomaly: 0
# Scaled LBMP value: 20.4
# Time: 2001-06-03T00:07:02Z, LBMP: 33.26, Scaled: 20.40, Residual: 20.99, Anomaly: 0
# Scaled LBMP value: 23.020000000000003
# Time: 2001-06-03T00:07:02Z, LBMP: 35.88, Scaled: 23.02, Residual: 23.64, Anomaly: 0
# Scaled LBMP value: 19.72
# Time: 2001-06-03T00:07:02Z, LBMP: 32.58, Scaled: 19.72, Residual: 20.36, Anomaly: 0
# Scaled LBMP value: 21.869999999999997
# Time: 2001-06-03T00:07:02Z, LBMP: 34.73, Scaled: 21.87, Residual: 22.51, Anomaly: 0
# Scaled LBMP value: 21.299999999999997
# Time: 2001-06-03T00:07:02Z, LBMP: 34.16, Scaled: 21.30, Residual: 21.94, Anomaly: 0
# Scaled LBMP value: 27.11
# Time: 2001-06-03T00:08:32Z, LBMP: 39.97, Scaled: 27.11, Residual: 27.76, Anomaly: 1
# Scaled LBMP value: 24.480000000000004
# Time: 2001-06-03T00:08:32Z, LBMP: 37.34, Scaled: 24.48, Residual: 25.08, Anomaly: 0
# Scaled LBMP value: 25.47
# Time: 2001-06-03T00:08:32Z, LBMP: 38.33, Scaled: 25.47, Residual: 26.01, Anomaly: 0
# Scaled LBMP value: 22.53
# Time: 2001-06-03T00:08:32Z, LBMP: 35.39, Scaled: 22.53, Residual: 23.02, Anomaly: 0
# Scaled LBMP value: 17.19
# Time: 2001-06-03T00:13:32Z, LBMP: 30.05, Scaled: 17.19, Residual: 17.65, Anomaly: 0
# Scaled LBMP value: 15.27
# Time: 2001-06-03T00:13:32Z, LBMP: 28.13, Scaled: 15.27, Residual: 15.72, Anomaly: 0
# Scaled LBMP value: 17.01
# Time: 2001-06-03T00:13:32Z, LBMP: 29.87, Scaled: 17.01, Residual: 17.45, Anomaly: 0
# Scaled LBMP value: 16.97
# Time: 2001-06-03T00:13:32Z, LBMP: 29.83, Scaled: 16.97, Residual: 17.41, Anomaly: 0
# Scaled LBMP value: 16.04
# Time: 2001-06-03T00:13:32Z, LBMP: 28.90, Scaled: 16.04, Residual: 16.42, Anomaly: 0
# Scaled LBMP value: 13.96
# Time: 2001-06-03T00:13:32Z, LBMP: 26.82, Scaled: 13.96, Residual: 14.28, Anomaly: 0
# Scaled LBMP value: 11.400000000000002
# Time: 2001-06-03T00:17:32Z, LBMP: 24.26, Scaled: 11.40, Residual: 11.68, Anomaly: 0
# Scaled LBMP value: 11.11
# Time: 2001-06-03T00:17:32Z, LBMP: 23.97, Scaled: 11.11, Residual: 11.36, Anomaly: 0
# Scaled LBMP value: 10.68
# Time: 2001-06-03T00:17:32Z, LBMP: 23.54, Scaled: 10.68, Residual: 10.91, Anomaly: 0
# Scaled LBMP value: 11.07
# Time: 2001-06-03T00:17:32Z, LBMP: 23.93, Scaled: 11.07, Residual: 11.30, Anomaly: 0
# Scaled LBMP value: 7.75
# Time: 2001-06-03T00:22:32Z, LBMP: 20.61, Scaled: 7.75, Residual: 7.98, Anomaly: 0
# Scaled LBMP value: 9.04
# Time: 2001-06-03T00:22:32Z, LBMP: 21.90, Scaled: 9.04, Residual: 9.26, Anomaly: 0
# Scaled LBMP value: 9.32
# Time: 2001-06-03T00:22:32Z, LBMP: 22.18, Scaled: 9.32, Residual: 9.53, Anomaly: 0
# Scaled LBMP value: 8.690000000000001
# Time: 2001-06-03T00:22:32Z, LBMP: 21.55, Scaled: 8.69, Residual: 8.90, Anomaly: 0
# Scaled LBMP value: 2.34
# Time: 2001-06-03T00:25:02Z, LBMP: 15.20, Scaled: 2.34, Residual: 2.55, Anomaly: 0
# Scaled LBMP value: 3.4800000000000004
# Time: 2001-06-03T00:25:02Z, LBMP: 16.34, Scaled: 3.48, Residual: 3.71, Anomaly: 0
# Scaled LBMP value: 3.289999999999999
# Time: 2001-06-03T00:25:02Z, LBMP: 16.15, Scaled: 3.29, Residual: 3.56, Anomaly: 0
# Scaled LBMP value: 3.040000000000001
# Time: 2001-06-03T00:25:02Z, LBMP: 15.90, Scaled: 3.04, Residual: 3.33, Anomaly: 0
# Scaled LBMP value: 2.780000000000001
# Time: 2001-06-03T00:25:02Z, LBMP: 15.64, Scaled: 2.78, Residual: 3.09, Anomaly: 0
# Scaled LBMP value: -12.76
# Time: 2001-06-03T00:30:02Z, LBMP: 0.10, Scaled: -12.76, Residual: -12.45, Anomaly: 1
# Scaled LBMP value: -12.76
# Time: 2001-06-03T00:30:02Z, LBMP: 0.10, Scaled: -12.76, Residual: -12.46, Anomaly: 1
# Scaled LBMP value: -12.76
# Time: 2001-06-03T00:30:02Z, LBMP: 0.10, Scaled: -12.76, Residual: -12.46, Anomaly: 1
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=3 host=34.95.23.216:19404 <connecting> [IPv4 ('34.95.23.216', 19404)]>: Connect attempt returned error 110. Disconnecting.
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=3 host=34.95.23.216:19404 <connecting> [IPv4 ('34.95.23.216', 19404)]>: Closing connection. KafkaConnectionError: 110 ETIMEDOUT
# WARNING:kafka.client:Node 3 connection failed -- refreshing metadata
# Scaled LBMP value: -13.82
# Time: 2001-06-03T00:31:32Z, LBMP: -0.96, Scaled: -13.82, Residual: -13.52, Anomaly: 1
# Scaled LBMP value: -13.83
# Time: 2001-06-03T00:31:32Z, LBMP: -0.97, Scaled: -13.83, Residual: -13.53, Anomaly: 1
# Scaled LBMP value: -13.82
# Time: 2001-06-03T00:31:32Z, LBMP: -0.96, Scaled: -13.82, Residual: -13.52, Anomaly: 1
# Scaled LBMP value: -13.799999999999999
# Time: 2001-06-03T00:31:32Z, LBMP: -0.94, Scaled: -13.80, Residual: -13.47, Anomaly: 1
# Scaled LBMP value: -13.809999999999999
# Time: 2001-06-03T00:31:32Z, LBMP: -0.95, Scaled: -13.81, Residual: -13.45, Anomaly: 1
# Scaled LBMP value: -13.719999999999999
# Time: 2001-06-03T00:31:32Z, LBMP: -0.86, Scaled: -13.72, Residual: -13.34, Anomaly: 1
# Scaled LBMP value: 8.990000000000002
# Time: 2001-06-03T00:36:32Z, LBMP: 21.85, Scaled: 8.99, Residual: 9.38, Anomaly: 0
# Scaled LBMP value: 8.060000000000002
# Time: 2001-06-03T00:36:32Z, LBMP: 20.92, Scaled: 8.06, Residual: 8.46, Anomaly: 0
# Scaled LBMP value: 6.580000000000002
# Time: 2001-06-03T00:36:32Z, LBMP: 19.44, Scaled: 6.58, Residual: 6.98, Anomaly: 0
# Scaled LBMP value: 4.370000000000001
# Time: 2001-06-03T00:41:32Z, LBMP: 17.23, Scaled: 4.37, Residual: 4.77, Anomaly: 0
# Scaled LBMP value: 3.210000000000001
# Time: 2001-06-03T00:41:32Z, LBMP: 16.07, Scaled: 3.21, Residual: 3.61, Anomaly: 0
# Scaled LBMP value: 5.84
# Time: 2001-06-03T00:46:32Z, LBMP: 18.70, Scaled: 5.84, Residual: 6.24, Anomaly: 0
# Scaled LBMP value: 7.219999999999999
# Time: 2001-06-03T00:46:32Z, LBMP: 20.08, Scaled: 7.22, Residual: 7.63, Anomaly: 0
# Scaled LBMP value: 9.670000000000002
# Time: 2001-06-03T00:51:32Z, LBMP: 22.53, Scaled: 9.67, Residual: 10.08, Anomaly: 0
# Scaled LBMP value: 8.240000000000002
# Time: 2001-06-03T00:51:32Z, LBMP: 21.10, Scaled: 8.24, Residual: 8.65, Anomaly: 0
# Scaled LBMP value: 9.670000000000002
# Time: 2001-06-03T00:51:32Z, LBMP: 22.53, Scaled: 9.67, Residual: 10.08, Anomaly: 0
# Scaled LBMP value: 7.969999999999999
# Time: 2001-06-03T00:51:32Z, LBMP: 20.83, Scaled: 7.97, Residual: 8.38, Anomaly: 0
# Scaled LBMP value: 9.150000000000002
# Time: 2001-06-03T00:51:32Z, LBMP: 22.01, Scaled: 9.15, Residual: 9.56, Anomaly: 0
# Scaled LBMP value: 9.36
# Time: 2001-06-03T00:51:32Z, LBMP: 22.22, Scaled: 9.36, Residual: 9.77, Anomaly: 0
# Scaled LBMP value: 7.300000000000001
# Time: 2001-06-03T00:51:32Z, LBMP: 20.16, Scaled: 7.30, Residual: 7.71, Anomaly: 0
# Scaled LBMP value: 36.6
# Time: 2001-06-03T00:53:32Z, LBMP: 49.46, Scaled: 36.60, Residual: 37.01, Anomaly: 1
# Scaled LBMP value: 36.43
# Time: 2001-06-03T00:53:32Z, LBMP: 49.29, Scaled: 36.43, Residual: 36.84, Anomaly: 1
# Scaled LBMP value: 35.13
# Time: 2001-06-03T00:53:32Z, LBMP: 47.99, Scaled: 35.13, Residual: 35.54, Anomaly: 1
# Scaled LBMP value: 35.7
# Time: 2001-06-03T00:55:32Z, LBMP: 48.56, Scaled: 35.70, Residual: 36.11, Anomaly: 1
# Scaled LBMP value: 38.980000000000004
# Time: 2001-06-03T00:55:32Z, LBMP: 51.84, Scaled: 38.98, Residual: 39.39, Anomaly: 1
# Scaled LBMP value: 38.44
# Time: 2001-06-03T00:55:32Z, LBMP: 51.30, Scaled: 38.44, Residual: 38.85, Anomaly: 1
# Scaled LBMP value: 37.88
# Time: 2001-06-03T01:00:00Z, LBMP: 50.74, Scaled: 37.88, Residual: 38.29, Anomaly: 1
# Scaled LBMP value: 39.82
# Time: 2001-06-03T01:00:32Z, LBMP: 52.68, Scaled: 39.82, Residual: 40.23, Anomaly: 1
# Scaled LBMP value: 35.980000000000004
# Time: 2001-06-03T01:00:32Z, LBMP: 48.84, Scaled: 35.98, Residual: 36.39, Anomaly: 1
# Scaled LBMP value: 35.5
# Time: 2001-06-03T01:00:32Z, LBMP: 48.36, Scaled: 35.50, Residual: 35.92, Anomaly: 1
# Scaled LBMP value: 38.61
# Time: 2001-06-03T01:00:32Z, LBMP: 51.47, Scaled: 38.61, Residual: 39.03, Anomaly: 1
# Scaled LBMP value: 37.31
# Time: 2001-06-03T01:00:32Z, LBMP: 50.17, Scaled: 37.31, Residual: 37.73, Anomaly: 1
# Scaled LBMP value: 30.07
# Time: 2001-06-03T01:05:32Z, LBMP: 42.93, Scaled: 30.07, Residual: 30.49, Anomaly: 1
# Scaled LBMP value: 30.42
# Time: 2001-06-03T01:05:32Z, LBMP: 43.28, Scaled: 30.42, Residual: 30.84, Anomaly: 1
# Scaled LBMP value: 29.28
# Time: 2001-06-03T01:05:32Z, LBMP: 42.14, Scaled: 29.28, Residual: 29.70, Anomaly: 1
# Scaled LBMP value: 30.07
# Time: 2001-06-03T01:07:02Z, LBMP: 42.93, Scaled: 30.07, Residual: 30.49, Anomaly: 1
# Scaled LBMP value: 29.28
# Time: 2001-06-03T01:07:02Z, LBMP: 42.14, Scaled: 29.28, Residual: 29.70, Anomaly: 1
# Scaled LBMP value: 40.29
# Time: 2001-06-03T01:11:02Z, LBMP: 53.15, Scaled: 40.29, Residual: 40.71, Anomaly: 1
# Scaled LBMP value: 36.21
# Time: 2001-06-03T01:11:02Z, LBMP: 49.07, Scaled: 36.21, Residual: 36.62, Anomaly: 1
# Scaled LBMP value: 35.64
# Time: 2001-06-03T01:11:02Z, LBMP: 48.50, Scaled: 35.64, Residual: 36.05, Anomaly: 1
# Scaled LBMP value: 37.52
# Time: 2001-06-03T01:16:02Z, LBMP: 50.38, Scaled: 37.52, Residual: 37.93, Anomaly: 1
# Scaled LBMP value: 29.910000000000004
# Time: 2001-06-03T01:17:32Z, LBMP: 42.77, Scaled: 29.91, Residual: 30.32, Anomaly: 1
# Scaled LBMP value: 32.93
# Time: 2001-06-03T01:17:32Z, LBMP: 45.79, Scaled: 32.93, Residual: 33.34, Anomaly: 1
# Scaled LBMP value: 29.32
# Time: 2001-06-03T01:17:32Z, LBMP: 42.18, Scaled: 29.32, Residual: 29.73, Anomaly: 0
# Scaled LBMP value: 31.060000000000002
# Time: 2001-06-03T01:17:32Z, LBMP: 43.92, Scaled: 31.06, Residual: 31.47, Anomaly: 1
# Scaled LBMP value: 28.07
# Time: 2001-06-03T01:17:32Z, LBMP: 40.93, Scaled: 28.07, Residual: 28.48, Anomaly: 0
# Scaled LBMP value: 37.61
# Time: 2001-06-03T01:22:02Z, LBMP: 50.47, Scaled: 37.61, Residual: 38.02, Anomaly: 1
# Scaled LBMP value: 35.95
# Time: 2001-06-03T01:22:02Z, LBMP: 48.81, Scaled: 35.95, Residual: 36.36, Anomaly: 1
# Scaled LBMP value: 31.54
# Time: 2001-06-03T01:22:02Z, LBMP: 44.40, Scaled: 31.54, Residual: 31.95, Anomaly: 1
# Scaled LBMP value: 29.53
# Time: 2001-06-03T01:27:02Z, LBMP: 42.39, Scaled: 29.53, Residual: 29.94, Anomaly: 0
# Scaled LBMP value: 25.700000000000003
# Time: 2001-06-03T01:27:02Z, LBMP: 38.56, Scaled: 25.70, Residual: 26.09, Anomaly: 0
# Scaled LBMP value: 27.43
# Time: 2001-06-03T01:27:02Z, LBMP: 40.29, Scaled: 27.43, Residual: 27.79, Anomaly: 0
# Scaled LBMP value: 24.42
# Time: 2001-06-03T01:27:02Z, LBMP: 37.28, Scaled: 24.42, Residual: 24.77, Anomaly: 0
# Scaled LBMP value: 28.04
# Time: 2001-06-03T01:32:02Z, LBMP: 40.90, Scaled: 28.04, Residual: 28.37, Anomaly: 0
# ...
# Scaled LBMP value: -13.889999999999999
# Time: 2001-06-03T03:18:32Z, LBMP: -1.03, Scaled: -13.89, Residual: -13.45, Anomaly: 1
# Scaled LBMP value: -13.94
# Time: 2001-06-03T03:18:32Z, LBMP: -1.08, Scaled: -13.94, Residual: -13.50, Anomaly: 1
# Scaled LBMP value: -13.94
# Time: 2001-06-03T03:18:32Z, LBMP: -1.08, Scaled: -13.94, Residual: -13.52, Anomaly: 1
# Scaled LBMP value: -13.92
# Time: 2001-06-03T03:18:32Z, LBMP: -1.06, Scaled: -13.92, Residual: -13.51, Anomaly: 1
# Scaled LBMP value: -13.85
# Time: 2001-06-03T03:18:32Z, LBMP: -0.99, Scaled: -13.85, Residual: -13.46, Anomaly: 1
# Scaled LBMP value: -13.959999999999999
# Time: 2001-06-03T03:23:32Z, LBMP: -1.10, Scaled: -13.96, Residual: -13.57, Anomaly: 1
# Scaled LBMP value: -13.95
# Time: 2001-06-03T03:23:32Z, LBMP: -1.09, Scaled: -13.95, Residual: -13.57, Anomaly: 1
# Scaled LBMP value: -13.889999999999999
# Time: 2001-06-03T03:23:32Z, LBMP: -1.03, Scaled: -13.89, Residual: -13.51, Anomaly: 1
# Scaled LBMP value: -13.94
# Time: 2001-06-03T03:23:32Z, LBMP: -1.08, Scaled: -13.94, Residual: -13.56, Anomaly: 1
# Scaled LBMP value: -13.93
# Time: 2001-06-03T03:23:32Z, LBMP: -1.07, Scaled: -13.93, Residual: -13.56, Anomaly: 1
# Scaled LBMP value: -13.94
# Time: 2001-06-03T03:23:32Z, LBMP: -1.08, Scaled: -13.94, Residual: -13.58, Anomaly: 1
# Scaled LBMP value: -13.889999999999999
# Time: 2001-06-03T03:28:38Z, LBMP: -1.03, Scaled: -13.89, Residual: -13.53, Anomaly: 1
# Scaled LBMP value: -13.93
# Time: 2001-06-03T03:28:38Z, LBMP: -1.07, Scaled: -13.93, Residual: -13.58, Anomaly: 1
# Scaled LBMP value: -13.92
# Time: 2001-06-03T03:28:38Z, LBMP: -1.06, Scaled: -13.92, Residual: -13.57, Anomaly: 1
# Scaled LBMP value: -13.93
# Time: 2001-06-03T03:33:32Z, LBMP: -1.07, Scaled: -13.93, Residual: -13.58, Anomaly: 1
# Scaled LBMP value: -13.889999999999999
# Time: 2001-06-03T03:36:02Z, LBMP: -1.03, Scaled: -13.89, Residual: -13.54, Anomaly: 1
# Scaled LBMP value: -13.95
# Time: 2001-06-03T03:36:02Z, LBMP: -1.09, Scaled: -13.95, Residual: -13.60, Anomaly: 1
# Scaled LBMP value: -13.93
# Time: 2001-06-03T03:36:02Z, LBMP: -1.07, Scaled: -13.93, Residual: -13.58, Anomaly: 1
# Scaled LBMP value: -13.94
# Time: 2001-06-03T03:36:02Z, LBMP: -1.08, Scaled: -13.94, Residual: -13.59, Anomaly: 1
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=1 host=34.118.173.179:19404 <connecting> [IPv4 ('34.118.173.179', 19404)]>: Connect attempt returned error 110. Disconnecting.
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=1 host=34.118.173.179:19404 <connecting> [IPv4 ('34.118.173.179', 19404)]>: Closing connection. KafkaConnectionError: 110 ETIMEDOUT
# WARNING:kafka.client:Node 1 connection failed -- refreshing metadata
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=2 host=35.203.26.124:19404 <connecting> [IPv4 ('35.203.26.124', 19404)]>: Connect attempt returned error 110. Disconnecting.
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=2 host=35.203.26.124:19404 <connecting> [IPv4 ('35.203.26.124', 19404)]>: Closing connection. KafkaConnectionError: 110 ETIMEDOUT
# WARNING:kafka.client:Node 2 connection failed -- refreshing metadata
# Scaled LBMP value: -13.879999999999999
# Time: 2001-06-03T03:40:32Z, LBMP: -1.02, Scaled: -13.88, Residual: -13.53, Anomaly: 1
# Scaled LBMP value: -13.94
# Time: 2001-06-03T03:40:32Z, LBMP: -1.08, Scaled: -13.94, Residual: -13.59, Anomaly: 1
# Scaled LBMP value: -13.879999999999999
# Time: 2001-06-03T03:40:32Z, LBMP: -1.02, Scaled: -13.88, Residual: -13.54, Anomaly: 1
# Scaled LBMP value: -13.879999999999999
# Time: 2001-06-03T03:44:32Z, LBMP: -1.02, Scaled: -13.88, Residual: -13.54, Anomaly: 0
# Scaled LBMP value: -13.91
# Time: 2001-06-03T03:44:32Z, LBMP: -1.05, Scaled: -13.91, Residual: -13.57, Anomaly: 0
# Scaled LBMP value: -13.95
# Time: 2001-06-03T03:49:32Z, LBMP: -1.09, Scaled: -13.95, Residual: -13.61, Anomaly: 0
# Scaled LBMP value: -13.879999999999999
# Time: 2001-06-03T03:49:32Z, LBMP: -1.02, Scaled: -13.88, Residual: -13.54, Anomaly: 0
# Scaled LBMP value: -13.93
# Time: 2001-06-03T03:49:32Z, LBMP: -1.07, Scaled: -13.93, Residual: -13.60, Anomaly: 0
# Scaled LBMP value: -13.879999999999999
# Time: 2001-06-03T03:54:32Z, LBMP: -1.02, Scaled: -13.88, Residual: -13.55, Anomaly: 0
# Scaled LBMP value: -13.93
# Time: 2001-06-03T03:54:32Z, LBMP: -1.07, Scaled: -13.93, Residual: -13.61, Anomaly: 0
# Scaled LBMP value: -13.91
# Time: 2001-06-03T03:54:32Z, LBMP: -1.05, Scaled: -13.91, Residual: -13.60, Anomaly: 0
# Scaled LBMP value: -13.85
# Time: 2001-06-03T03:54:32Z, LBMP: -0.99, Scaled: -13.85, Residual: -13.54, Anomaly: 0
# Scaled LBMP value: -13.12
# Time: 2001-06-03T03:56:02Z, LBMP: -0.26, Scaled: -13.12, Residual: -12.81, Anomaly: 0
# Scaled LBMP value: -13.129999999999999
# Time: 2001-06-03T03:56:02Z, LBMP: -0.27, Scaled: -13.13, Residual: -12.81, Anomaly: 0
# Scaled LBMP value: -13.12
# Time: 2001-06-03T03:56:02Z, LBMP: -0.26, Scaled: -13.12, Residual: -12.80, Anomaly: 0
# Scaled LBMP value: -13.129999999999999
# Time: 2001-06-03T03:56:02Z, LBMP: -0.27, Scaled: -13.13, Residual: -12.81, Anomaly: 0
# Scaled LBMP value: -13.129999999999999
# Time: 2001-06-03T03:56:02Z, LBMP: -0.27, Scaled: -13.13, Residual: -12.81, Anomaly: 0
# Scaled LBMP value: -13.11
# Time: 2001-06-03T03:56:02Z, LBMP: -0.25, Scaled: -13.11, Residual: -12.79, Anomaly: 0
# Scaled LBMP value: -13.12
# Time: 2001-06-03T04:00:00Z, LBMP: -0.26, Scaled: -13.12, Residual: -12.80, Anomaly: 0
# Scaled LBMP value: -13.129999999999999
# Time: 2001-06-03T04:00:00Z, LBMP: -0.27, Scaled: -13.13, Residual: -12.81, Anomaly: 0
# Scaled LBMP value: -13.129999999999999
# Time: 2001-06-03T04:00:00Z, LBMP: -0.27, Scaled: -13.13, Residual: -12.81, Anomaly: 0
# Scaled LBMP value: -13.129999999999999
# Time: 2001-06-03T04:00:00Z, LBMP: -0.27, Scaled: -13.13, Residual: -12.81, Anomaly: 0
# Scaled LBMP value: -13.11
# Time: 2001-06-03T04:00:00Z, LBMP: -0.25, Scaled: -13.11, Residual: -12.79, Anomaly: 0
# Scaled LBMP value: 7.719999999999999
# Time: 2001-06-03T04:01:02Z, LBMP: 20.58, Scaled: 7.72, Residual: 8.03, Anomaly: 0
# Scaled LBMP value: 8.5
# Time: 2001-06-03T04:01:02Z, LBMP: 21.36, Scaled: 8.50, Residual: 8.81, Anomaly: 0
# Scaled LBMP value: 8.510000000000002
# Time: 2001-06-03T04:01:02Z, LBMP: 21.37, Scaled: 8.51, Residual: 8.82, Anomaly: 0
# Scaled LBMP value: 8.260000000000002
# Time: 2001-06-03T04:01:02Z, LBMP: 21.12, Scaled: 8.26, Residual: 8.57, Anomaly: 0
# Scaled LBMP value: 7.02
# Time: 2001-06-03T04:01:02Z, LBMP: 19.88, Scaled: 7.02, Residual: 7.33, Anomaly: 0
# Scaled LBMP value: 38.160000000000004
# Time: 2001-06-03T04:05:32Z, LBMP: 51.02, Scaled: 38.16, Residual: 38.47, Anomaly: 1
# Scaled LBMP value: 35.74
# Time: 2001-06-03T04:05:32Z, LBMP: 48.60, Scaled: 35.74, Residual: 36.05, Anomaly: 1
# Scaled LBMP value: 36.980000000000004
# Time: 2001-06-03T04:05:32Z, LBMP: 49.84, Scaled: 36.98, Residual: 37.29, Anomaly: 1
# Scaled LBMP value: 35.46
# Time: 2001-06-03T04:08:32Z, LBMP: 48.32, Scaled: 35.46, Residual: 35.77, Anomaly: 1
# Scaled LBMP value: 37.99
# Time: 2001-06-03T04:08:32Z, LBMP: 50.85, Scaled: 37.99, Residual: 38.30, Anomaly: 1
# Scaled LBMP value: 35.6
# Time: 2001-06-03T04:08:32Z, LBMP: 48.46, Scaled: 35.60, Residual: 35.91, Anomaly: 1
# Scaled LBMP value: 37.64
# Time: 2001-06-03T04:08:32Z, LBMP: 50.50, Scaled: 37.64, Residual: 37.95, Anomaly: 1
# Scaled LBMP value: 37.43
# Time: 2001-06-03T04:08:32Z, LBMP: 50.29, Scaled: 37.43, Residual: 37.78, Anomaly: 1
# Scaled LBMP value: 33.79
# Time: 2001-06-03T04:08:32Z, LBMP: 46.65, Scaled: 33.79, Residual: 34.19, Anomaly: 1
# Scaled LBMP value: 32.68
# Time: 2001-06-03T04:13:32Z, LBMP: 45.54, Scaled: 32.68, Residual: 33.11, Anomaly: 1
# Scaled LBMP value: 35.13
# Time: 2001-06-03T04:13:32Z, LBMP: 47.99, Scaled: 35.13, Residual: 35.59, Anomaly: 1
# Scaled LBMP value: 34.04
# Time: 2001-06-03T04:13:32Z, LBMP: 46.90, Scaled: 34.04, Residual: 34.51, Anomaly: 1
# Scaled LBMP value: 31.130000000000003
# Time: 2001-06-03T04:13:32Z, LBMP: 43.99, Scaled: 31.13, Residual: 31.60, Anomaly: 0
# Scaled LBMP value: 25.32
# Time: 2001-06-03T04:17:32Z, LBMP: 38.18, Scaled: 25.32, Residual: 25.79, Anomaly: 0
# Scaled LBMP value: 22.64
# Time: 2001-06-03T04:17:32Z, LBMP: 35.50, Scaled: 22.64, Residual: 23.12, Anomaly: 0
# Scaled LBMP value: 24.57
# Time: 2001-06-03T04:17:32Z, LBMP: 37.43, Scaled: 24.57, Residual: 25.03, Anomaly: 0
# Scaled LBMP value: 24.32
# Time: 2001-06-03T04:17:32Z, LBMP: 37.18, Scaled: 24.32, Residual: 24.75, Anomaly: 0
# Scaled LBMP value: 24.130000000000003
# Time: 2001-06-03T04:17:32Z, LBMP: 36.99, Scaled: 24.13, Residual: 24.55, Anomaly: 0
# Scaled LBMP value: 24.160000000000004
# Time: 2001-06-03T04:17:32Z, LBMP: 37.02, Scaled: 24.16, Residual: 24.57, Anomaly: 0
# Scaled LBMP value: 9.920000000000002
# Time: 2001-06-03T04:22:32Z, LBMP: 22.78, Scaled: 9.92, Residual: 10.33, Anomaly: 0
# Scaled LBMP value: 8.310000000000002
# Time: 2001-06-03T04:22:32Z, LBMP: 21.17, Scaled: 8.31, Residual: 8.72, Anomaly: 0
# Scaled LBMP value: 8.32
# Time: 2001-06-03T04:22:32Z, LBMP: 21.18, Scaled: 8.32, Residual: 8.73, Anomaly: 0
# Scaled LBMP value: 9.240000000000002
# Time: 2001-06-03T04:22:32Z, LBMP: 22.10, Scaled: 9.24, Residual: 9.65, Anomaly: 0
# Scaled LBMP value: 8.98
# Time: 2001-06-03T04:22:32Z, LBMP: 21.84, Scaled: 8.98, Residual: 9.39, Anomaly: 0
# Scaled LBMP value: 7.699999999999999
# Time: 2001-06-03T04:22:32Z, LBMP: 20.56, Scaled: 7.70, Residual: 8.13, Anomaly: 0
# Scaled LBMP value: 9.09
# Time: 2001-06-03T04:27:32Z, LBMP: 21.95, Scaled: 9.09, Residual: 9.53, Anomaly: 0
# Scaled LBMP value: 7.879999999999999
# Time: 2001-06-03T04:27:32Z, LBMP: 20.74, Scaled: 7.88, Residual: 8.34, Anomaly: 0
# Scaled LBMP value: 8.940000000000001
# Time: 2001-06-03T04:27:32Z, LBMP: 21.80, Scaled: 8.94, Residual: 9.41, Anomaly: 0
# Scaled LBMP value: 8.850000000000001
# Time: 2001-06-03T04:27:32Z, LBMP: 21.71, Scaled: 8.85, Residual: 9.32, Anomaly: 0
# Scaled LBMP value: 9.150000000000002
# Time: 2001-06-03T04:32:32Z, LBMP: 22.01, Scaled: 9.15, Residual: 9.62, Anomaly: 0
# Scaled LBMP value: 8.84
# Time: 2001-06-03T04:32:32Z, LBMP: 21.70, Scaled: 8.84, Residual: 9.32, Anomaly: 0
# Scaled LBMP value: 8.91
# Time: 2001-06-03T04:32:32Z, LBMP: 21.77, Scaled: 8.91, Residual: 9.39, Anomaly: 0
# Scaled LBMP value: 7.25
# Time: 2001-06-03T04:32:32Z, LBMP: 20.11, Scaled: 7.25, Residual: 7.73, Anomaly: 0
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=3 host=34.95.23.216:19404 <connecting> [IPv4 ('34.95.23.216', 19404)]>: Connect attempt returned error 110. Disconnecting.
# ERROR:kafka.conn:<BrokerConnection client_id=CONSUMER_CLIENT_ID, node_id=3 host=34.95.23.216:19404 <connecting> [IPv4 ('34.95.23.216', 19404)]>: Closing connection. KafkaConnectionError: 110 ETIMEDOUT
# WARNING:kafka.client:Node 3 connection failed -- refreshing metadata
# Scaled LBMP value: 9.3
# Time: 2001-06-03T04:34:08Z, LBMP: 22.16, Scaled: 9.30, Residual: 9.78, Anomaly: 0
# Scaled LBMP value: 7.670000000000002
# Time: 2001-06-03T04:34:08Z, LBMP: 20.53, Scaled: 7.67, Residual: 8.15, Anomaly: 0
# Scaled LBMP value: 8.650000000000002
# Time: 2001-06-03T04:34:08Z, LBMP: 21.51, Scaled: 8.65, Residual: 9.11, Anomaly: 0
# Scaled LBMP value: 8.719999999999999
# Time: 2001-06-03T04:34:08Z, LBMP: 21.58, Scaled: 8.72, Residual: 9.17, Anomaly: 0
# Scaled LBMP value: 8.41
# Time: 2001-06-03T04:34:08Z, LBMP: 21.27, Scaled: 8.41, Residual: 8.85, Anomaly: 0
# Scaled LBMP value: 7.100000000000001
# Time: 2001-06-03T04:34:08Z, LBMP: 19.96, Scaled: 7.10, Residual: 7.53, Anomaly: 0
# Scaled LBMP value: 9.170000000000002
# Time: 2001-06-03T04:39:02Z, LBMP: 22.03, Scaled: 9.17, Residual: 9.59, Anomaly: 0
# Scaled LBMP value: 7.57
# Time: 2001-06-03T04:39:02Z, LBMP: 20.43, Scaled: 7.57, Residual: 7.99, Anomaly: 0
# Scaled LBMP value: 8.830000000000002
# Time: 2001-06-03T04:39:02Z, LBMP: 21.69, Scaled: 8.83, Residual: 9.25, Anomaly: 0
# Scaled LBMP value: 7.52
# Time: 2001-06-03T04:39:02Z, LBMP: 20.38, Scaled: 7.52, Residual: 7.94, Anomaly: 0
# Scaled LBMP value: 8.670000000000002
# Time: 2001-06-03T04:39:02Z, LBMP: 21.53, Scaled: 8.67, Residual: 9.08, Anomaly: 0
# Scaled LBMP value: 8.260000000000002
# Time: 2001-06-03T04:39:02Z, LBMP: 21.12, Scaled: 8.26, Residual: 8.67, Anomaly: 0
# Scaled LBMP value: 1.08
# Time: 2001-06-03T04:44:02Z, LBMP: 13.94, Scaled: 1.08, Residual: 1.48, Anomaly: 0
# Scaled LBMP value: 1.8200000000000003
# Time: 2001-06-03T04:44:02Z, LBMP: 14.68, Scaled: 1.82, Residual: 2.22, Anomaly: 0
# Scaled LBMP value: 0.7000000000000011
# Time: 2001-06-03T04:44:02Z, LBMP: 13.56, Scaled: 0.70, Residual: 1.10, Anomaly: 0
# Scaled LBMP value: 1.7800000000000011
# Time: 2001-06-03T04:49:02Z, LBMP: 14.64, Scaled: 1.78, Residual: 2.18, Anomaly: 0
# Scaled LBMP value: 0.6300000000000008
# Time: 2001-06-03T04:49:02Z, LBMP: 13.49, Scaled: 0.63, Residual: 1.03, Anomaly: 0
# Scaled LBMP value: 3.0600000000000005
# Time: 2001-06-03T04:54:02Z, LBMP: 15.92, Scaled: 3.06, Residual: 3.46, Anomaly: 0
# Scaled LBMP value: 3.870000000000001
# Time: 2001-06-03T04:54:02Z, LBMP: 16.73, Scaled: 3.87, Residual: 4.27, Anomaly: 0
# Scaled LBMP value: 3.780000000000001
# Time: 2001-06-03T04:54:02Z, LBMP: 16.64, Scaled: 3.78, Residual: 4.19, Anomaly: 0
# Scaled LBMP value: 3.6000000000000014
# Time: 2001-06-03T04:54:02Z, LBMP: 16.46, Scaled: 3.60, Residual: 4.01, Anomaly: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-a123a12c7677> in <cell line: 0>()
#      36 print("Listening to Kafka stream...")
#      37
# ---> 38 for message in consumer:
#      39     message_str = message.value.decode('utf-8')
#      40
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in __next__(self)
#    1188                 self._iterator = self._message_generator_v2()
#    1189             try:
# -> 1190                 return next(self._iterator)
#    1191             except StopIteration:
#    1192                 self._iterator = None
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1160     def _message_generator_v2(self):
#    1161         timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1162         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1163         for tp, records in six.iteritems(record_map):
#    1164             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     682         inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     683         while not self._closed:
# --> 684             records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     685             if records:
#     686                 return records
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     728             poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
#     729
# --> 730         self._client.poll(timeout_ms=poll_timeout_ms)
#     731         # after the long poll, we should check whether the group needs to rebalance
#     732         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     687                     timeout = max(0, timeout)  # avoid negative timeouts
#     688
# --> 689                 self._poll(timeout / 1000)
#     690
#     691             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     730
#     731         start_select = time.time()
# --> 732         ready = self._selector.select(timeout)
#     733         end_select = time.time()
#     734         if self._sensors:
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:

# %% [markdown]
# As observed from the results the anomaly though at certain areas not correct does correctly predict the too obvious ones which is important
